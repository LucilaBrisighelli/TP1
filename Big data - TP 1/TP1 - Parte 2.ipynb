# %% [markdown]
# # Curso de Big Data. Otoño 2024
#
# ## Trabajo Práctico 1 - Parte 2

# %% [markdown]
# ### Reglas de formato y presentación
# - El trabajo debe estar bien comentado (utilizando #) para que el código sea fácil de entender por sus compañeros y profesores.
#
# - El mismo debe ser completado en este Jupyter Notebook y entregado como tal, es decir en un archivo .ipynb

# %% [markdown]
# ### Fecha de entrega:
# Domingo 24 de marzo a las 23:59hs

# %% [markdown]
# ### Modalidad de entrega
# - Al finalizar el trabajo práctico deben hacer un último <i>commit</i> en su repositorio de GitHub con el mensaje “Entrega final del tp”.
# - Asegurense de haber creado una carpeta llamada TP1. Este Jupyter Notebook y el correspondiente al TP1 - Parte 2 deben estar dentro de esa carpeta.
# - También deben enviar el link de su repositorio -para que pueda ser clonado y corregido- al siguiente email: v.oubina@gmail.com
# - La última versión en el repositorio es la que será evaluada. Por lo que es importante que:
#     - No envien el correo hasta no haber terminado y estar seguros de que han hecho el <i>commit y push</i> a la versión final que quieren entregar. Debido a que se pueden tomar hasta 3 días de extensión a lo largo del curso, no se corregirán sus tareas hasta no recibir el correo.
#     - No hagan nuevos <i>push</i> despues de haber entregado su versión final. Esto generaría confusión acerca de que versión es la que quieren que se les corrija.

# %% [markdown]
# ### Parte A

# %% [markdown]
# #### Ejercicio 1
# Usando la API de Mercado Libre, obtener los ítems de una consulta de búsqueda. Pueden buscar cualquier producto de su interés.

# %%
import requests 
# la búsqueda en el navegador es la siguiente:  
# https://listado.mercadolibre.com.ar/bicicleta#D[A:bicicleta]
# Como usamos la API seguimos este formato:
# https://api.mercadolibre.com/sites/$MLA/search?q=bicicleta%20item
# Recordamos que
# $SITE_ID: MLA  # MLA es el sitio de Argentina
# item: item a buscar. (reemplazamos los espacios con %20)

buscar = "bicileta"
url = "https://api.mercadolibre.com/sites/{}/search?q={}".format("MLA", buscar.replace(" ", "%20"))

# Hacemos el pedido o request y obtenemos la response
response = requests.request("GET", url)
print(response) # correcto

# Vemos el texto
response.text
# Out:
# <Response [200]>
# '{"site_id":"MLA","country_default_time_zone":"GMT-03:00","query":"bicileta","paging":{"total":19933,"primary_results":1000,"offset":0,"limit":50},"results":[{"id":"MLA1147844417","title":"Bicicleta Silverfox R29 21v Mtb Aluminio 29 Freno Disco Susp Color Naranja Tamaño Del Cuadro 18","condition":"new","thumbnail_id":"659217-MLU73459629072_122023","catalog_product_id":"MLA23755521","listing_type_id":"gold_special","permalink":"https://www.mercadolibre.com.ar/bicicleta-silverfox-r29-21v-mtb-aluminio-29-freno-disco-susp-color-naranja-tamano-del-cuadro-18/p/MLA23755521","buying_mode":"buy_it_now","site_id":"MLA","category_id":"MLA6143","domain_id":"MLA-BICYCLES","thumbnail":"http://http2.mlstatic.com/D_659217-MLU73459629072_122023-I.jpg","currency_id":"ARS","order_backend":1,"price":258099.11,"original_price":289999,"sale_price":null,"available_quantity":50,"official_store_id":null,"use_thumbnail_id":true,"accepts_mercadopago":true,"shipping":{"store_pick_up":false,"free_shipping":true,"logistic_type":"cross_docking","mode":"me2","tags":["self_service_in","mandatory_free_shipping"],"benefits":null,"promise":null},"stop_time":"2043-12-08T14:48:19.000Z","seller":{"id":70513647,"nickname":"GARIOTTI"},"attributes":[{"id":"BRAND","name":"Marca","value_id":"10445553","value_name":"Silverfox","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"10445553","name":"Silverfox","struct":null,"source":1}],"source":1,"value_type":"string"},{"id":"DETAILED_MODEL","name":"Modelo detallado","value_id":"28471959","value_name":"Silverfox R29","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"28471959","name":"Silverfox R29","struct":null,"source":1}],"source":1,"value_type":"string"},{"id":"FILTRABLE_GENDER","name":"Género filtrables","value_id":"18549360","value_name":"Hombre","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"18549360","name":"Hombre","struct":null,"source":7363830417619661}],"source":7363830417619661,"value_type":"list"},{"id":"GENDER","name":"Género","value_id":"110461","value_name":"Sin género","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"110461","name":"Sin género","struct":null,"source":1}],"source":1,"value_type":"list"},{"id":"GTIN","name":"Código universal de producto","value_id":null,"value_name":"07796962987833","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":null,"name":"07796962987833","struct":null,"source":1}],"source":1,"value_type":"string"},{"id":"ITEM_CONDITION","name":"Condición del ítem","value_id":"2230284","value_name":"Nuevo","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"2230284","name":"Nuevo","struct":null,"source":377188858949192}],"source":377188858949192,"value_type":"list"},{"id":"MODEL","name":"Modelo","value_id":"10382","value_name":"210","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"10382","name":"210","struct":null,"source":1}],"source":1,"value_type":"string"},{"id":"WEIGHT","name":"Peso","value_id":"203369","value_name":"15 kg","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":{"number":15,"unit":"kg"},"values":[{"id":"203369","name":"15 kg","struct":{"unit":"kg","number":15},"source":1}],"source":1,"value_type":"number_unit"}],"installments":{"quantity":6,"amount":68361.85,"rate":58.92,"currency_id":"ARS"},"winner_item_id":null,"catalog_listing":true,"discounts":null,"promotions":[],"inventory_id":null},{"id":"MLA1387611463","title":"Mountain Bike Gadnic Mountain Mtb29 L 21v Cambios Shimano Color Verde Con Pie De Apoyo  ","condition":"new","thumbnail_id":"760548-MLA53861075844_022023","catalog_product_id":"MLA21774271","listing_type_id":"gold_special","permalink":"https://www.mercadolibre.com.ar/mountain-bike-gadnic-mountain-mtb2 ...

# %%
url
# Out:
# 'https://api.mercadolibre.com/sites/MLA/search?q=bicileta'

# %%
#Guardamos el resultado en un diccionario (json)
data = response.json()
#type(data) # dict
data
# Out:
# {'site_id': 'MLA',
#  'country_default_time_zone': 'GMT-03:00',
#  'query': 'bicileta',
#  'paging': {'total': 19933, 'primary_results': 1000, 'offset': 0, 'limit': 50},
#  'results': [{'id': 'MLA1147844417',
#    'title': 'Bicicleta Silverfox R29 21v Mtb Aluminio 29 Freno Disco Susp Color Naranja Tamaño Del Cuadro 18',
#    'condition': 'new',
#    'thumbnail_id': '659217-MLU73459629072_122023',
#    'catalog_product_id': 'MLA23755521',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/bicicleta-silverfox-r29-21v-mtb-aluminio-29-freno-disco-susp-color-naranja-tamano-del-cuadro-18/p/MLA23755521',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA6143',
#    'domain_id': 'MLA-BICYCLES',
#    'thumbnail': 'http://http2.mlstatic.com/D_659217-MLU73459629072_122023-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 1,
#    'price': 258099.11,
#    'original_price': 289999,
#    'sale_price': None,
#    'available_quantity': 50,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['self_service_in', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2043-12-08T14:48:19.000Z',
#    'seller': {'id': 70513647, 'nickname': 'GARIOTTI'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '10445553',
#      'value_name': 'Silverfox',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '10445553',
#        'name': 'Silverfox',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'DETAILED_MODEL',
#      'name': 'Modelo detallado',
#      'value_id': '28471959',
#      'value_name': 'Silverfox R29',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '28471959',
#        'name': 'Silverfox R29',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'FILTRABLE_GENDER',
#      'name': 'Género filtrables',
#      'value_id': '18549360',
#      'value_name': 'Hombre',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '18549360',
#        'name': 'Hombre',
#        'struct': None,
#        'source': 7363830417619661}],
#      'source': 7363830417619661,
#      'value_type': 'list'},
#     {'id': 'GENDER',
#      'name': 'Género',
#      'value_id': '110461',
#      'value_name': 'Sin género',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '110461',
#        'name': 'Sin género',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '07796962987833',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '07796962987833',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 377188858949192}],
#      'source': 377188858949192,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '10382',
#      'value_name': '210',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '10382', 'name': '210', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '203369',
#      'value_name': '15 kg',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 15, 'unit': 'kg'},
#      'values': [{'id': '203369',
#        'name': '15 kg',
#        'struct': {'unit': 'kg', 'number': 15},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 68361.85,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1387611463',
#    'title': 'Mountain Bike Gadnic Mountain Mtb29 L 21v Cambios Shimano Color Verde Con Pie De Apoyo  ',
#    'condition': 'new',
#    'thumbnail_id': '760548-MLA53861075844_022023',
#    'catalog_product_id': 'MLA21774271',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/mountain-bike-gadnic-mountain-mtb29-l-21v-cambios-shimano-color-verde-con-pie-de-apoyo/p/MLA21774271',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA6143',
#    'domain_id': 'MLA-BICYCLES',
#    'thumbnail': 'http://http2.mlstatic.com/D_760548-MLA53861075844_022023-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 2,
#    'price': 249999,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': 945,
#    'official_store_name': 'Gadnic',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['self_service_out', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2043-09-06T04:00:00.000Z',
#    'seller': {'id': 37133205, 'nickname': 'BIDCOM STORES'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '410974',
#      'value_name': 'Gadnic',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '410974',
#        'name': 'Gadnic',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'FILTRABLE_GENDER',
#      'name': 'Género filtrables',
#      'value_id': None,
#      'value_name': 'Mujer,Hombre',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '18549361',
#        'name': 'Mujer',
#        'struct': None,
#        'source': 7363830417619661},
#       {'id': '18549360',
#        'name': 'Hombre',
#        'struct': None,
#        'source': 7363830417619661}],
#      'source': 7363830417619661,
#      'value_type': 'list'},
#     {'id': 'GENDER',
#      'name': 'Género',
#      'value_id': '110461',
#      'value_name': 'Sin género',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '110461',
#        'name': 'Sin género',
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'list'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '7427250812864',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '7427250812864',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '4936382',
#      'value_name': 'Mountain',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '4936382',
#        'name': 'Mountain',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '16843255',
#      'value_name': 'Mtb29',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '16843255',
#        'name': 'Mtb29',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '925808',
#      'value_name': '16.4 kg',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 16.4, 'unit': 'kg'},
#      'values': [{'id': '925808',
#        'name': '16.4 kg',
#        'struct': {'unit': 'kg', 'number': 16.4},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 66216.4,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA928174090',
#    'title': 'Mountain Bike Sunny Mtl 290 M 21v Frenos De Disco Mecánico Cambios Sun Run Y Shimano Tourney Color Negro/celeste Con Pie De Apoyo  ',
#    'condition': 'new',
#    'thumbnail_id': '667903-MLU73118250218_122023',
#    'catalog_product_id': 'MLA17921666',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/mountain-bike-sunny-mtl-290-m-21v-frenos-de-disco-mecanico-cambios-sun-run-y-shimano-tourney-color-negroceleste-con-pie-de-apoyo/p/MLA17921666',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA6143',
#    'domain_id': 'MLA-BICYCLES',
#    'thumbnail': 'http://http2.mlstatic.com/D_667903-MLU73118250218_122023-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 3,
#    'price': 237599.12,
#    'original_price': 269999,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['self_service_in', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2043-11-27T15:07:53.000Z',
#    'seller': {'id': 70513647, 'nickname': 'GARIOTTI'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '928609',
#      'value_name': 'Sunny',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '928609',
#        'name': 'Sunny',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'FILTRABLE_GENDER',
#      'name': 'Género filtrables',
#      'value_id': '18549360',
#      'value_name': 'Hombre',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '18549360',
#        'name': 'Hombre',
#        'struct': None,
#        'source': 7363830417619661}],
#      'source': 7363830417619661,
#      'value_type': 'list'},
#     {'id': 'GENDER',
#      'name': 'Género',
#      'value_id': '110461',
#      'value_name': 'Sin género',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '110461',
#        'name': 'Sin género',
#        'struct': None,
#        'source': 4709228965570453}],
#      'source': 4709228965570453,
#      'value_type': 'list'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '10392994',
#      'value_name': 'MTL 290',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '10392994',
#        'name': 'MTL 290',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '7553596',
#      'value_name': '17.45 kg',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 17.45, 'unit': 'kg'},
#      'values': [{'id': '7553596',
#        'name': '17.45 kg',
#        'struct': {'unit': 'kg', 'number': 17.45},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 62932.09,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA928173639',
#    'title': 'Bicicleta Sunny Modelo Mtl 290 Rodado 29 Negro Naranja Color Negro/naranja Tamaño Del Cuadro M',
#    'condition': 'new',
#    'thumbnail_id': '869742-MLU75124708986_032024',
#    'catalog_product_id': 'MLA17921665',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/bicicleta-sunny-modelo-mtl-290-rodado-29-negro-naranja-color-negronaranja-tamano-del-cuadro-m/p/MLA17921665',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA6143',
#    'domain_id': 'MLA-BICYCLES',
#    'thumbnail': 'http://http2.mlstatic.com/D_869742-MLU75124708986_032024-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 4,
#    'price': 237599.12,
#    'original_price': 269999,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['self_service_in', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2043-11-27T15:07:54.000Z',
#    'seller': {'id': 70513647, 'nickname': 'GARIOTTI'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '928609',
#      'value_name': 'Sunny',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '928609',
#        'name': 'Sunny',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'FILTRABLE_GENDER',
#      'name': 'Género filtrables',
#      'value_id': '18549360',
#      'value_name': 'Hombre',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '18549360',
#        'name': 'Hombre',
#        'struct': None,
#        'source': 7363830417619661}],
#      'source': 7363830417619661,
#      'value_type': 'list'},
#     {'id': 'GENDER',
#      'name': 'Género',
#      'value_id': '110461',
#      'value_name': 'Sin género',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '110461',
#        'name': 'Sin género',
#        'struct': None,
#        'source': 4709228965570453}],
#      'source': 4709228965570453,
#      'value_type': 'list'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '10392994',
#      'value_name': 'MTL 290',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '10392994',
#        'name': 'MTL 290',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '7553596',
#      'value_name': '17.45 kg',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 17.45, 'unit': 'kg'},
#      'values': [{'id': '7553596',
#        'name': '17.45 kg',
#        'struct': {'number': 17.45, 'unit': 'kg'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 62932.09,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA930322230',
#    'title': 'Futura Country Adultos - Rosa - 26 - V-brakes - V-brakes + Pie De Apoyo)',
#    'condition': 'new',
#    'thumbnail_id': '814026-MLA43347649337_092020',
#    'catalog_product_id': 'MLA15990441',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/futura-country-adultos-rosa-26-v-brakes-v-brakes-pie-de-apoyo/p/MLA15990441',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA6143',
#    'domain_id': 'MLA-BICYCLES',
#    'thumbnail': 'http://http2.mlstatic.com/D_814026-MLA43347649337_092020-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 5,
#    'price': 193760,
#    'original_price': 242200,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['self_service_in', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2042-05-25T12:48:46.000Z',
#    'seller': {'id': 355576322, 'nickname': 'MORASHOP.AR'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '5452174',
#      'value_name': 'Futura',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '5452174',
#        'name': 'Futura',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'FILTRABLE_GENDER',
#      'name': 'Género filtrables',
#      'value_id': '18549361',
#      'value_name': 'Mujer',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '18549361',
#        'name': 'Mujer',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'list'},
#     {'id': 'GENDER',
#      'name': 'Género',
#      'value_id': '339665',
#      'value_name': 'Mujer',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '339665',
#        'name': 'Mujer',
#        'struct': None,
#        'source': 4709228965570453}],
#      'source': 4709228965570453,
#      'value_type': 'list'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6808261514773724}],
#      'source': 6808261514773724,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '135703',
#      'value_name': 'Country',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '135703',
#        'name': 'Country',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'}],
#    'installments': {'quantity': 6,
#     'amount': 51320.57,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'NYZA73666'},
#   {'id': 'MLA1518128398',
#    'title': 'Bicicleta Mtb Overtech R29 Acero 21v Freno A Disco Pp Color Negro/rojo/blanco Tamaño Del Cuadro M',
#    'condition': 'new',
#    'thumbnail_id': '623172-MLU72894563146_112023',
#    'catalog_product_id': 'MLA26080681',
#    'listing_type_id': 'gold_pro',
#    'permalink': 'https://www.mercadolibre.com.ar/bicicleta-mtb-overtech-r29-acero-21v-freno-a-disco-pp-color-negrorojoblanco-tamano-del-cuadro-m/p/MLA26080681',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA6143',
#    'domain_id': 'MLA-BICYCLES',
#    'thumbnail': 'http://http2.mlstatic.com/D_623172-MLU72894563146_112023-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 6,
#    'price': 274999,
#    'original_price': 399999,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['self_service_in', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2043-09-20T04:00:00.000Z',
#    'seller': {'id': 174556876, 'nickname': 'OVERHARD'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '399528',
#      'value_name': 'Overtech',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '399528',
#        'name': 'Overtech',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'DETAILED_MODEL',
#      'name': 'Modelo detallado',
#      'value_id': '20558341',
#      'value_name': 'Overtech Q5',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '20558341',
#        'name': 'Overtech Q5',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'FILTRABLE_GENDER',
#      'name': 'Género filtrables',
#      'value_id': '18549360',
#      'value_name': 'Hombre',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '18549360',
#        'name': 'Hombre',
#        'struct': None,
#        'source': 7363830417619661}],
#      'source': 7363830417619661,
#      'value_type': 'list'},
#     {'id': 'GENDER',
#      'name': 'Género',
#      'value_id': '110461',
#      'value_name': 'Sin género',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '110461',
#        'name': 'Sin género',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '20558337',
#      'value_name': 'R29',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '20558337',
#        'name': 'R29',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '20793993',
#      'value_name': 'Overtech Q5',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '20793993',
#        'name': 'Overtech Q5',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '925877',
#      'value_name': '18 kg',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 18, 'unit': 'kg'},
#      'values': [{'id': '925877',
#        'name': '18 kg',
#        'struct': {'unit': 'kg', 'number': 18},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 3,
#     'amount': 91666.33,
#     'rate': 0,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'differential_pricing': {'id': 35713384},
#    'inventory_id': None},
#   {'id': 'MLA1512897736',
#    'title': 'Bicicleta Infantil Nena De Paseo Rodado 12 Canasto Color Blanco',
#    'condition': 'new',
#    'thumbnail_id': '738550-MLU72637658637_112023',
#    'catalog_product_id': 'MLA26633319',
#    'listing_type_id': 'gold_pro',
#    'permalink': 'https://www.mercadolibre.com.ar/bicicleta-infantil-nena-de-paseo-rodado-12-canasto-color-blanco/p/MLA26633319',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA6143',
#    'domain_id': 'MLA-BICYCLES',
#    'thumbnail': 'http://http2.mlstatic.com/D_738550-MLU72637658637_112023-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 7,
#    'price': 174999,
#    'original_price': 275999,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': 2380,
#    'official_store_name': 'Macro Baby',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment', 'self_service_out', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2043-09-15T04:00:00.000Z',
#    'seller': {'id': 377828679, 'nickname': 'MACRO BABY'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '27028',
#      'value_name': 'GTS',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '27028', 'name': 'GTS', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'FILTRABLE_GENDER',
#      'name': 'Género filtrables',
#      'value_id': '18549361',
#      'value_name': 'Mujer',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '18549361',
#        'name': 'Mujer',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'list'},
#     {'id': 'GENDER',
#      'name': 'Género',
#      'value_id': '339665',
#      'value_name': 'Mujer',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '339665',
#        'name': 'Mujer',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '7798100078533',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '7798100078533',
#        'struct': None,
#        'source': 8910742901282450}],
#      'source': 8910742901282450,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '23723843',
#      'value_name': 'R12 Paseo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '23723843',
#        'name': 'R12 Paseo',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '1072381',
#      'value_name': '9 kg',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 9, 'unit': 'kg'},
#      'values': [{'id': '1072381',
#        'name': '9 kg',
#        'struct': {'unit': 'kg', 'number': 9},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 29166.5,
#     'rate': 0,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'differential_pricing': {'id': 33678187},
#    'inventory_id': 'GFCN90284'},
#   {'id': 'MLA1414179209',
#    'title': 'Bicicleta Thunder Sky 2.0 R29 21 Velocidades Frenos Mecánicos',
#    'condition': 'new',
#    'thumbnail_id': '686263-MLU74319608476_022024',
#    'catalog_product_id': 'MLA19151114',
#    'listing_type_id': 'gold_pro',
#    'permalink': 'https://www.mercadolibre.com.ar/bicicleta-thunder-sky-20-r29-21-velocidades-frenos-mecanicos/p/MLA19151114',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA6143',
#    'domain_id': 'MLA-BICYCLES',
#    'thumbnail': 'http://http2.mlstatic.com/D_686263-MLU74319608476_022024-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 8,
#    'price': 315999.21,
#    'original_price': 399999,
#    'sale_price': None,
#    'available_quantity': 50,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['self_service_in', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2044-03-07T04:00:00.000Z',
#    'seller': {'id': 145868636, 'nickname': 'OPENFACTORY'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '2785981',
#      'value_name': 'Thunder',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2785981',
#        'name': 'Thunder',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'DETAILED_MODEL',
#      'name': 'Modelo detallado',
#      'value_id': '18839319',
#      'value_name': 'Sky',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '18839319',
#        'name': 'Sky',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GENDER',
#      'name': 'Género',
#      'value_id': '110461',
#      'value_name': 'Sin género',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '110461',
#        'name': 'Sin género',
#        'struct': None,
#        'source': 4709228965570453}],
#      'source': 4709228965570453,
#      'value_type': 'list'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '7798366203274',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '7798366203274',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '12315807',
#      'value_name': 'Sky 2.0',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '12315807',
#        'name': 'Sky 2.0',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '203369',
#      'value_name': '15 kg',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 15, 'unit': 'kg'},
#      'values': [{'id': '203369',
#        'name': '15 kg',
#        'struct': {'number': 15, 'unit': 'kg'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 52666.54,
#     'rate': 0,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'differential_pricing': {'id': 33678187},
#    'inventory_id': None},
#   {'id': 'MLA1400826691',
#    'title': 'Mountain Bike Venzo Shadow Series Loki Evo R29 20  21v Frenos De Disco Mecánico Cambios Shimano Color Negro/rojo  ',
#    'condition': 'new',
#    'thumbnail_id': '993287-MLA44939467215_022021',
#    'catalog_product_id': 'MLA17352038',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/mountain-bike-venzo-shadow-series-loki-evo-r29-20-21v-frenos-de-disco-mecanico-cambios-shimano-color-negrorojo/p/MLA17352038',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA6143',
#    'domain_id': 'MLA-BICYCLES',
#    'thumbnail': 'http://http2.mlstatic.com/D_993287-MLA44939467215_022021-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 9,
#    'price': 389753,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'xd_drop_off',
#     'mode': 'me2',
#     'tags': ['self_service_in', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2043-12-26T04:00:00.000Z',
#    'seller': {'id': 735026202, 'nickname': 'GOLDENBIKE LELOIR'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '454150',
#      'value_name': 'Venzo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '454150',
#        'name': 'Venzo',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'DETAILED_MODEL',
#      'name': 'Modelo detallado',
#      'value_id': '28225624',
#      'value_name': 'Loki',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '28225624',
#        'name': 'Loki',
#        'struct': None,
#        'source': 4709228965570453}],
#      'source': 4709228965570453,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '9806646',
#      'value_name': 'Shadow Series',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '9806646',
#        'name': 'Shadow Series',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '9806647',
#      'value_name': 'Loki Evo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '9806647',
#        'name': 'Loki Evo',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '203369',
#      'value_name': '15 kg',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 15, 'unit': 'kg'},
#      'values': [{'id': '203369',
#        'name': '15 kg',
#        'struct': {'number': 15, 'unit': 'kg'},
#        'source': 4709228965570453}],
#      'source': 4709228965570453,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 103232.58,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1518128400',
#    'title': 'Bicicleta Mtb Overtech R29 Acero 21v Freno A Disco Pp Color Negro/rojo/blanco Tamaño Del Cuadro S',
#    'condition': 'new',
#    'thumbnail_id': '960352-MLU72892503218_112023',
#    'catalog_product_id': 'MLA26080679',
#    'listing_type_id': 'gold_pro',
#    'permalink': 'https://www.mercadolibre.com.ar/bicicleta-mtb-overtech-r29-acero-21v-freno-a-disco-pp-color-negrorojoblanco-tamano-del-cuadro-s/p/MLA26080679',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA6143',
#    'domain_id': 'MLA-BICYCLES',
#    'thumbnail': 'http://http2.mlstatic.com/D_960352-MLU72892503218_112023-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 10,
#    'price': 274999,
#    'original_price': 399999,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['self_service_in', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2043-09-20T04:00:00.000Z',
#    'seller': {'id': 174556876, 'nickname': 'OVERHARD'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '399528',
#      'value_name': 'Overtech',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '399528',
#        'name': 'Overtech',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'DETAILED_MODEL',
#      'name': 'Modelo detallado',
#      'value_id': '20558341',
#      'value_name': 'Overtech Q5',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '20558341',
#        'name': 'Overtech Q5',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'FILTRABLE_GENDER',
#      'name': 'Género filtrables',
#      'value_id': '18549360',
#      'value_name': 'Hombre',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '18549360',
#        'name': 'Hombre',
#        'struct': None,
#        'source': 7363830417619661}],
#      'source': 7363830417619661,
#      'value_type': 'list'},
#     {'id': 'GENDER',
#      'name': 'Género',
#      'value_id': '110461',
#      'value_name': 'Sin género',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '110461',
#        'name': 'Sin género',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '20558337',
#      'value_name': 'R29',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '20558337',
#        'name': 'R29',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '20793993',
#      'value_name': 'Overtech Q5',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '20793993',
#        'name': 'Overtech Q5',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '925877',
#      'value_name': '18 kg',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 18, 'unit': 'kg'},
#      'values': [{'id': '925877',
#        'name': '18 kg',
#        'struct': {'number': 18, 'unit': 'kg'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 3,
#     'amount': 91666.33,
#     'rate': 0,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'differential_pricing': {'id': 35713384},
#    'inventory_id': None},
#   {'id': 'MLA1518128416',
#    'title': 'Bicicleta Mtb Overtech R29 Acero 21v Freno A Disco Pp Color Negro/naranja/blanco Tamaño Del Cuadro M',
#    'condition': 'new',
#    'thumbnail_id': '903938-MLA71900518134_092023',
#    'catalog_product_id': 'MLA24541785',
#    'listing_type_id': 'gold_pro',
#    'permalink': 'https://www.mercadolibre.com.ar/bicicleta-mtb-overtech-r29-acero-21v-freno-a-disco-pp-color-negronaranjablanco-tamano-del-cuadro-m/p/MLA24541785',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA6143',
#    'domain_id': 'MLA-BICYCLES',
#    'thumbnail': 'http://http2.mlstatic.com/D_903938-MLA71900518134_092023-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 11,
#    'price': 274999,
#    'original_price': 399999,
#    'sale_price': None,
#    'available_quantity': 100,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['self_service_in', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2043-09-20T04:00:00.000Z',
#    'seller': {'id': 174556876, 'nickname': 'OVERHARD'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '399528',
#      'value_name': 'Overtech',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '399528',
#        'name': 'Overtech',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'DETAILED_MODEL',
#      'name': 'Modelo detallado',
#      'value_id': '20558341',
#      'value_name': 'Overtech Q5',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '20558341',
#        'name': 'Overtech Q5',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'FILTRABLE_GENDER',
#      'name': 'Género filtrables',
#      'value_id': '18549360',
#      'value_name': 'Hombre',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '18549360',
#        'name': 'Hombre',
#        'struct': None,
#        'source': 7363830417619661}],
#      'source': 7363830417619661,
#      'value_type': 'list'},
#     {'id': 'GENDER',
#      'name': 'Género',
#      'value_id': '110461',
#      'value_name': 'Sin género',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '110461',
#        'name': 'Sin género',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '20558337',
#      'value_name': 'R29',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '20558337',
#        'name': 'R29',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '20793993',
#      'value_name': 'Overtech Q5',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '20793993',
#        'name': 'Overtech Q5',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '925877',
#      'value_name': '18 kg',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 18, 'unit': 'kg'},
#      'values': [{'id': '925877',
#        'name': '18 kg',
#        'struct': {'number': 18, 'unit': 'kg'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 3,
#     'amount': 91666.33,
#     'rate': 0,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'differential_pricing': {'id': 35713384},
#    'inventory_id': None},
#   {'id': 'MLA1399800546',
#    'title': 'Mountain Bike Venzo Shadow Series Loki Evo R29 20  21v Frenos De Disco Mecánico Cambios Shimano Color Negro/teal  ',
#    'condition': 'new',
#    'thumbnail_id': '682936-MLA44939295785_022021',
#    'catalog_product_id': 'MLA17352028',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/mountain-bike-venzo-shadow-series-loki-evo-r29-20-21v-frenos-de-disco-mecanico-cambios-shimano-color-negroteal/p/MLA17352028',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA6143',
#    'domain_id': 'MLA-BICYCLES',
#    'thumbnail': 'http://http2.mlstatic.com/D_682936-MLA44939295785_022021-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 12,
#    'price': 384090,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'xd_drop_off',
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2043-04-13T04:00:00.000Z',
#    'seller': {'id': 107349484, 'nickname': 'FACCHINBICYCLESCBA'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '454150',
#      'value_name': 'Venzo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '454150',
#        'name': 'Venzo',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'DETAILED_MODEL',
#      'name': 'Modelo detallado',
#      'value_id': '28225624',
#      'value_name': 'Loki',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '28225624',
#        'name': 'Loki',
#        'struct': None,
#        'source': 4709228965570453}],
#      'source': 4709228965570453,
#      'value_type': 'string'},
#     {'id': 'FILTRABLE_GENDER',
#      'name': 'Género filtrables',
#      'value_id': None,
#      'value_name': 'Mujer,Hombre',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '18549361',
# ...
#     {'id': '454144', 'name': 'L', 'results': 1956},
#     {'id': '454141', 'name': 'S', 'results': 1515},
#     {'id': '5842285', 'name': '20 "', 'results': 918},
#     {'id': '5861499', 'name': '16 "', 'results': 618},
#     {'id': '457283', 'name': 'XL', 'results': 552},
#     {'id': '5861506', 'name': '18 "', 'results': 471},
#     {'id': '457282', 'name': 'XS', 'results': 336},
#     {'id': '5861496', 'name': '14 "', 'results': 222},
#     {'id': '5861501', 'name': '17 "', 'results': 210},
#     {'id': '5700369', 'name': '19 "', 'results': 180},
#     {'id': '5861513', 'name': '21 "', 'results': 135},
#     {'id': '11722547', 'name': '26', 'results': 135},
#     {'id': '5861497', 'name': '15 "', 'results': 117},
#     {'id': '7051466', 'name': '54 cm', 'results': 99},
#     {'id': '457284', 'name': 'XXL', 'results': 87},
#     {'id': '7126671', 'name': '55 cm', 'results': 81},
#     {'id': '8262595', 'name': 'Único', 'results': 72},
#     {'id': '7126669', 'name': '50 cm', 'results': 69},
#     {'id': '7126664', 'name': '45 cm', 'results': 63},
#     {'id': '7126670', 'name': '52 cm', 'results': 60},
#     {'id': '11376983', 'name': '12', 'results': 54},
#     {'id': '7126667', 'name': '48 cm', 'results': 39},
#     {'id': '7051463', 'name': '53 cm', 'results': 39},
#     {'id': '22770225', 'name': '24', 'results': 36},
#     {'id': '6440299', 'name': '28 "', 'results': 33},
#     {'id': '6130032', 'name': 'ML', 'results': 33},
#     {'id': '7126665', 'name': '46 cm', 'results': 24},
#     {'id': '12083173', 'name': '21', 'results': 24},
#     {'id': '24592018', 'name': '16"', 'results': 21},
#     {'id': '24026390', 'name': '21"', 'results': 21},
#     {'id': '7195262', 'name': '16.5 "', 'results': 18},
#     {'id': '7051465', 'name': '51 cm', 'results': 18},
#     {'id': '6409747', 'name': '26 "', 'results': 18},
#     {'id': '11393626', 'name': '17', 'results': 18},
#     {'id': '8279670', 'name': '56 "', 'results': 15},
#     {'id': '8279667', 'name': '54 "', 'results': 15},
#     {'id': '8276885', 'name': '51', 'results': 15},
#     {'id': '7126668', 'name': '49 cm', 'results': 15},
#     {'id': '24133451', 'name': 'M 18 "', 'results': 15},
#     {'id': '18647316', 'name': '53', 'results': 15},
#     {'id': '13258682', 'name': '29', 'results': 15},
#     {'id': '11393624', 'name': '19', 'results': 15},
#     {'id': '7411231', 'name': 'SM', 'results': 12},
#     {'id': '6409751', 'name': '12 "', 'results': 12},
#     {'id': '25936943', 'name': '14"', 'results': 12},
#     {'id': '16525394', 'name': '54', 'results': 12},
#     {'id': '11462929', 'name': '15', 'results': 12},
#     {'id': '7495656', 'name': '60 cm', 'results': 9},
#     {'id': '7126666', 'name': '47 cm', 'results': 9},
#     {'id': '25933549', 'name': '26"', 'results': 9},
#     {'id': '24061285', 'name': 'L 19', 'results': 9},
#     {'id': '24041416', 'name': '19"', 'results': 9},
#     {'id': '16525389', 'name': '52', 'results': 9},
#     {'id': '11996284', 'name': '24 "', 'results': 9},
#     {'id': '11394596', 'name': '18', 'results': 9},
#     {'id': '8279665', 'name': '50 "', 'results': 6},
#     {'id': '7464493', 'name': '59 cm', 'results': 6},
#     {'id': '7464489', 'name': '56 cm', 'results': 6},
#     {'id': '6424798', 'name': '20.5 "', 'results': 6},
#     {'id': '5929902', 'name': '22 "', 'results': 6},
#     {'id': '5861508', 'name': '18.5 "', 'results': 6},
#     {'id': '24722146', 'name': 'S - 16 "', 'results': 6},
#     {'id': '24629070', 'name': 'M 18', 'results': 6},
#     {'id': '24026759', 'name': 'S 16 "', 'results': 6},
#     {'id': '24026389', 'name': '15"', 'results': 6},
#     {'id': '20269461', 'name': '19.5', 'results': 6},
#     {'id': '20079272', 'name': '48', 'results': 6},
#     {'id': '20079266', 'name': '56', 'results': 6},
#     {'id': '11649423', 'name': 'Mediano', 'results': 6},
#     {'id': '11394605', 'name': '20', 'results': 6},
#     {'id': '9801752', 'name': 'M/L', 'results': 3},
#     {'id': '8279669', 'name': '48 "', 'results': 3},
#     {'id': '8279666', 'name': '52 "', 'results': 3},
#     {'id': '7465990', 'name': '43 cm', 'results': 3},
#     {'id': '7464496', 'name': '58 cm', 'results': 3},
#     {'id': '7464492', 'name': '57 cm', 'results': 3},
#     {'id': '7336971', 'name': 'XXS', 'results': 3},
#     {'id': '6452142', 'name': '10 "', 'results': 3},
#     {'id': '6452140', 'name': '8 "', 'results': 3},
#     {'id': '5861519', 'name': '23 "', 'results': 3},
#     {'id': '5861498', 'name': '15.5 "', 'results': 3},
#     {'id': '25146478', 'name': 'M 17 "', 'results': 3},
#     {'id': '24214391', 'name': '56cm', 'results': 3},
#     {'id': '24205691', 'name': '24"', 'results': 3},
#     {'id': '24149015', 'name': 'M 17', 'results': 3},
#     {'id': '24149014', 'name': 'S 15', 'results': 3},
#     {'id': '24125669', 'name': '16.5', 'results': 3},
#     {'id': '24041418', 'name': '17"', 'results': 3},
#     {'id': '23938232', 'name': 'SX', 'results': 3},
#     {'id': '23786647', 'name': '27 "', 'results': 3},
#     {'id': '20269460', 'name': '17.5', 'results': 3},
#     {'id': '20115959', 'name': '50', 'results': 3},
#     {'id': '20079269', 'name': '58', 'results': 3},
#     {'id': '17512826', 'name': '13', 'results': 3},
#     {'id': '11410930', 'name': '11', 'results': 3}]},
#   {'id': 'FRONT_BRAKE_TYPE',
#    'name': 'Tipo de freno delantero',
#    'type': 'STRING',
#    'values': [{'id': '8117598', 'name': 'V-brakes', 'results': 3108},
#     {'id': '8117600', 'name': 'Disco mecánico', 'results': 2517},
#     {'id': '8117599', 'name': 'Disco hidráulico', 'results': 1623},
#     {'id': '8117596', 'name': 'Caliper', 'results': 528},
#     {'id': '16347602', 'name': 'Herradura', 'results': 411},
#     {'id': '8117597', 'name': 'Cantilever', 'results': 159},
#     {'id': '12979196', 'name': 'V-brake', 'results': 147},
#     {'id': '8183186', 'name': 'Disco', 'results': 96},
#     {'id': '15143683', 'name': 'Hidráulico', 'results': 69},
#     {'id': '14255107', 'name': 'a Disco', 'results': 33},
#     {'id': '8798466', 'name': 'U-brakes', 'results': 21},
#     {'id': '9498623', 'name': 'Varilla', 'results': 15},
#     {'id': '12290512', 'name': 'Shimano TZ50', 'results': 15},
#     {'id': '12104457', 'name': 'Contrapedal', 'results': 15},
#     {'id': '26418528', 'name': 'V-Brake Aluminio', 'results': 12},
#     {'id': '26079870', 'name': 'Disco hidráulico X-Spark', 'results': 12},
#     {'id': '25841316', 'name': 'V-brakes o contrapedal', 'results': 12},
#     {'id': '24025683', 'name': 'V-BREAK', 'results': 12},
#     {'id': '8199686', 'name': 'Tambor', 'results': 6},
#     {'id': '25149567', 'name': 'V-Brake alloy', 'results': 6},
#     {'id': '13258915', 'name': 'Disco semi-hidráulico', 'results': 6},
#     {'id': '26135832', 'name': 'Pinza', 'results': 3},
#     {'id': '24801860', 'name': 'V, Aluminum, Linear Spring', 'results': 3}]},
#   {'id': 'IS_FOLDABLE',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Es plegable', 'results': 777}]},
#   {'id': 'ITEM_CONDITION',
#    'name': 'Condición',
#    'type': 'STRING',
#    'values': [{'id': '2230581', 'name': 'Usado', 'results': 9174},
#     {'id': '2230284', 'name': 'Nuevo', 'results': 5958},
#     {'id': '2230582', 'name': 'Reacondicionado', 'results': 42}]},
#   {'id': 'MAIN_COLOR',
#    'name': 'Color principal',
#    'type': 'list',
#    'values': [{'id': '2450295', 'name': 'Negro', 'results': 2406},
#     {'id': '2450293', 'name': 'Azul', 'results': 891},
#     {'id': '2450307', 'name': 'Rojo', 'results': 846},
#     {'id': '2450312', 'name': 'Rosa', 'results': 696},
#     {'id': '2450308', 'name': 'Blanco', 'results': 651},
#     {'id': '2450314', 'name': 'Verde', 'results': 609},
#     {'id': '2450294', 'name': 'Gris', 'results': 477},
#     {'id': '2450278', 'name': 'Celeste', 'results': 426},
#     {'id': '2450311', 'name': 'Violeta', 'results': 402},
#     {'id': '2450327', 'name': 'Naranja', 'results': 336},
#     {'id': '2450296', 'name': 'Amarillo', 'results': 285},
#     {'id': '2450303', 'name': 'Plateado', 'results': 165},
#     {'id': '2450291', 'name': 'Marrón', 'results': 72},
#     {'id': '2450289', 'name': 'Dorado', 'results': 33},
#     {'id': '2450299', 'name': 'Gris oscuro', 'results': 3}]},
#   {'id': 'MAX_WEIGHT_SUPPORTED',
#    'name': 'Peso máximo soportado',
#    'type': 'range',
#    'values': [{'id': '(*-90kg)', 'name': 'Menos de 90 kg', 'results': 1500},
#     {'id': '[90kg-115kg)', 'name': '90 a 114 kg', 'results': 1728},
#     {'id': '[115kg-125kg)', 'name': '115 a 124 kg', 'results': 1575},
#     {'id': '[125kg-*)', 'name': '125 kg o más', 'results': 1245}]},
#   {'id': 'MIN_RECOMMENDED_AGE',
#    'name': 'Edad mínima recomendada',
#    'type': 'range',
#    'values': [{'id': '(*-6años)', 'name': 'Menos de 6 años', 'results': 1107},
#     {'id': '[6años-10años)', 'name': '6 a 9 años', 'results': 882},
#     {'id': '[10años-14años)', 'name': '10 a 13 años', 'results': 1680},
#     {'id': '[14años-16años)', 'name': '14 a 15 años', 'results': 738},
#     {'id': '[16años-*)', 'name': '16 años o más', 'results': 369}]},
#   {'id': 'REAR_BRAKE_TYPE',
#    'name': 'Tipo de freno trasero',
#    'type': 'STRING',
#    'values': [{'id': '6382000', 'name': 'V-brakes', 'results': 3021},
#     {'id': '6440294', 'name': 'Disco mecánico', 'results': 2472},
#     {'id': '6440297', 'name': 'Disco hidráulico', 'results': 1647},
#     {'id': '6760910', 'name': 'Caliper', 'results': 492},
#     {'id': '16520106', 'name': 'Herradura', 'results': 372},
#     {'id': '6427368', 'name': 'Contrapedal', 'results': 360},
#     {'id': '6760911', 'name': 'Cantilever', 'results': 168},
#     {'id': '12979199', 'name': 'V-brake', 'results': 156},
#     {'id': '7099459', 'name': 'Disco', 'results': 102},
#     {'id': '15143686', 'name': 'Hidráulico', 'results': 66},
#     {'id': '8587885', 'name': 'U-brakes', 'results': 45},
#     {'id': '25841315', 'name': 'V-brakes o contrapedal', 'results': 42},
#     {'id': '1095866', 'name': 'Manual', 'results': 27},
#     {'id': '433353', 'name': 'Mecánico', 'results': 21},
#     {'id': '23548159', 'name': 'Cinta/Tambor', 'results': 15},
#     {'id': '12290513', 'name': 'Sunrun QD35', 'results': 15},
#     {'id': '9498624', 'name': 'Varilla', 'results': 12},
#     {'id': '26079867', 'name': 'Disco hidráulico X-Spark', 'results': 12},
#     {'id': '6450740', 'name': 'Tambor', 'results': 9},
#     {'id': '26418527', 'name': 'V-Brake Aluminio', 'results': 9},
#     {'id': '13258916', 'name': 'Disco semi-hidráulico', 'results': 6},
#     {'id': '24801859', 'name': 'V, Aluminum, Linear Spring', 'results': 3},
#     {'id': '23814529', 'name': 'Campana', 'results': 3}]},
#   {'id': 'REQUIRES_ASSEMBLY',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242084',
#      'name': 'No requiere ensamblado',
#      'results': 6300}]},
#   {'id': 'WHEEL_SIZE',
#    'name': 'Rodado',
#    'type': 'range',
#    'values': [{'id': '[29-29]', 'name': 'Rodado 29', 'results': 3720},
#     {'id': '[28-28]', 'name': 'Rodado 28', 'results': 1185},
#     {'id': '[27.5-27.5]', 'name': 'Rodado 27.5', 'results': 111},
#     {'id': '[27-27]', 'name': 'Rodado 27', 'results': 36},
#     {'id': '[26-26]', 'name': 'Rodado 26', 'results': 2661},
#     {'id': '[24-24]', 'name': 'Rodado 24', 'results': 621},
#     {'id': '[22-22]', 'name': 'Rodado 22', 'results': 9},
#     {'id': '[21-21]', 'name': 'Rodado 21', 'results': 6},
#     {'id': '[20-20]', 'name': 'Rodado 20', 'results': 2250},
#     {'id': '[19-19]', 'name': 'Rodado 19', 'results': 3},
#     {'id': '[18-18]', 'name': 'Rodado 18', 'results': 18},
#     {'id': '[17-17]', 'name': 'Rodado 17', 'results': 3},
#     {'id': '[16-16]', 'name': 'Rodado 16', 'results': 1083},
#     {'id': '[15-15]', 'name': 'Rodado 15', 'results': 24},
#     {'id': '[14-14]', 'name': 'Rodado 14', 'results': 192},
#     {'id': '[12-12]', 'name': 'Rodado 12', 'results': 687}]},
#   {'id': 'WITH_BASKET',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Con canasto', 'results': 1785}]},
#   {'id': 'WITH_KICKSTAND',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Con pie de apoyo', 'results': 4401}]},
#   {'id': 'WITH_POSITIVE_IMPACT',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Con impacto positivo',
#      'results': 15174}]},
#   {'id': 'WITH_TRAINING_WHEELS',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Con ruedas de entrenamiento',
#      'results': 1623}]},
#   {'id': 'product',
#    'name': 'Producto',
#    'type': 'text',
#    'values': [{'id': 'MLA14703109',
#      'name': 'Bicicleta Infantil Raleigh Jazzi R20 V-brakes Rosa/blanco',
#      'results': 5},
#     {'id': 'MLA12942910',
#      'name': 'Mountain bike Futura Techno 026 18" 21v frenos v-brakes cambios Index color blanco con pie de apoyo  ',
#      'results': 1},
#     {'id': 'MLA13198332',
#      'name': 'Bicicleta paseo infantil Raleigh Lilhon R16 freno v-brakes color blanco/rosa  ',
#      'results': 1},
#     {'id': 'MLA13286067',
#      'name': 'Bicicleta freestyle masculina Peretti Freestyle Extreme III R20 1v frenos v-brakes color plateado con pie de apoyo  ',
#      'results': 1},
#     {'id': 'MLA14067570',
#      'name': 'Bicicleta infantil Olmo Tiny Dancers R20 frenos v-brakes color rosa',
#      'results': 1}]}],
#  'pdp_tracking': {'group': False,
#   'product_info': [{'id': 'MLA23755521', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA21774271', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA17921666', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA17921665', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA15990441', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA26080681', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA26633319', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19151114', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA17352038', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA26080679', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA24541785', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA17352028', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19472826', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA17921629', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA25925844', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA27602844', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA26340086', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA26340090', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA17352026', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA17352043', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA26626258', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19472829', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA12942910', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA26080682', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA16028698', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA21094535', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA25354224', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA15967539', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA17352048', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA27473853', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA14703109', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA18333516', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA16246866', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA27286610', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA26600937', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA15980112', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA26503124', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA24526223', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA15967541', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA26600936', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA26854295', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA26503122', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA26205932', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA26688782', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA17352037', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA15751394', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA14869534', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA17921628', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA26194858', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA16001527', 'score': 1, 'status': 'shown'}]}}

# %% [markdown]
# #### Ejercicio 2
# Guarden los precios de los ítems obtenidos en un dataframe y calculen el precio promedio, el mínimo y el máximo.

# %%
import pandas as pd

# %%
import sys
# !{sys.executable} -m pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/lucilabrisighelligatti/anaconda3/lib/python3.11/site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/lucilabrisighelligatti/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/lucilabrisighelligatti/anaconda3/lib/python3.11/site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/lucilabrisighelligatti/anaconda3/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /Users/lucilabrisighelligatti/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
# primero creamos una lista para guardar los precios de los ítems.
precios = []
# buscamos en los resultados para extraer los precios
for item in data['results']:
    precios.append(item['price'])
# ahora creamos un dataFrame con los precios
df_precios = pd.DataFrame(precios, columns=['Precio'])

# definimos nuestras variables que calculan el precio promedio, mínimo y máximo y luego imprimos los resultados.
precio_promedio = df_precios['Precio'].mean()
precio_minimo = df_precios['Precio'].min()
precio_maximo = df_precios['Precio'].max()

print("precio promedio:", precio_promedio)
print("el mínimo:", precio_minimo)
print("el máximo:", precio_maximo)
# Out:
# precio promedio: 245896.99159999995
# el mínimo: 81579.73
# el máximo: 389753.0

# %% [markdown]
# #### Ejercicio 3
# Armen un histograma de los precios. ¿Ven algún <i>outlier<i>?
# Nota: pueden usar la librería de Matplotlib o la de Pandas.

# %%
#imprtamos matplotlib
import matplotlib.pyplot as plt
import pandas as pd
# creamos el histograma de los precios (usamoss la libreria de Pandas)
df_precios.hist(bins=30, color="red", edgecolor='black')

plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.title('Histograma de Precios')

plt.show()

# %% [markdown]
# #### Ejercicio 4
# Realicen alguna consulta adicional utilizando la API de Mercado Libre (debe ser alguna consulta que no se haya visto en clase. Por ejemplo, obtener los ítems de un vendedor en particular, obtener los productos de una categoría u otros). Analicen los resultados y comenten uno o dos que les parezcan interesantes (por ejemplo, precios promedio de los productos de un vendedor, diferencia entre el precio original y actual, si acepta mercado pago para la compra de productos, etc.)

# %%
import requests 
#vamos a buscar los productos para la categoria "Accesorios para vehiculos" 
# "id": "MLA5725",
# "name": "Accesorios para Vehículos"
#Al usar la API tenemos que seguir este formato:
# https://api.mercadolibre.com/sites/$SITE_ID/search?category=$CATEGORY_ID

url = "https://api.mercadolibre.com//sites/MLA/search?category=5725"

# Hacemos el pedido o request y obtenemos la response
response = requests.request("GET", url)
print(response) 

# Vemos el texto
response.text
# Out:
# <Response [200]>
# '{"site_id":"MLA","country_default_time_zone":"GMT-03:00","paging":{"total":5918283,"primary_results":1000,"offset":0,"limit":50},"results":[{"id":"MLA1277641650","title":"Pack 4 Paños Microfibra Multiuso Limpieza Auto Hogar Oficina Color Varios","condition":"new","thumbnail_id":"797432-MLA44041279363_112020","catalog_product_id":"MLA20023033","listing_type_id":"gold_special","permalink":"https://www.mercadolibre.com.ar/pack-4-panos-microfibra-multiuso-limpieza-auto-hogar-oficina-color-varios/p/MLA20023033","buying_mode":"buy_it_now","site_id":"MLA","category_id":"MLA424491","domain_id":"MLA-CLEANING_CLOTHS","thumbnail":"http://http2.mlstatic.com/D_797432-MLA44041279363_112020-I.jpg","currency_id":"ARS","order_backend":1,"price":3830.4,"original_price":3830.4,"sale_price":null,"available_quantity":200,"official_store_id":null,"use_thumbnail_id":true,"accepts_mercadopago":true,"shipping":{"store_pick_up":false,"free_shipping":false,"logistic_type":"fulfillment","mode":"me2","tags":["fulfillment","self_service_in"],"benefits":null,"promise":null},"stop_time":"2042-12-04T04:00:00.000Z","seller":{"id":702150429,"nickname":"GLOBALNAVET"},"attributes":[{"id":"BRAND","name":"Marca","value_id":"9067552","value_name":"Laffitte","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"9067552","name":"Laffitte","struct":null,"source":1}],"source":1,"value_type":"string"},{"id":"GTIN","name":"Código universal de producto","value_id":null,"value_name":"7792993337968","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":null,"name":"7792993337968","struct":null,"source":385122562515662}],"source":1,"value_type":"string"},{"id":"ITEM_CONDITION","name":"Condición del ítem","value_id":"2230284","value_name":"Nuevo","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"2230284","name":"Nuevo","struct":null,"source":2860837171021627}],"source":2860837171021627,"value_type":"list"},{"id":"LENGTH","name":"Largo","value_id":"7879371","value_name":"30 cm","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":{"number":30,"unit":"cm"},"values":[{"id":"7879371","name":"30 cm","struct":{"number":30,"unit":"cm"},"source":1}],"source":1,"value_type":"number_unit"},{"id":"MODEL","name":"Modelo","value_id":null,"value_name":"AJ01H","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":null,"name":"AJ01H","struct":null,"source":2860837171021627}],"source":2860837171021627,"value_type":"string"},{"id":"SALE_FORMAT","name":"Formato de venta","value_id":"1359392","value_name":"Pack","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"1359392","name":"Pack","struct":null,"source":1}],"source":1,"value_type":"list"},{"id":"UNITS_PER_PACK","name":"Unidades por pack","value_id":"2726556","value_name":"4","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"2726556","name":"4","struct":null,"source":1}],"source":1,"value_type":"number"},{"id":"UNITS_PER_PACKAGE","name":"Unidades por envase","value_id":"7916708","value_name":"4","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"7916708","name":"4","struct":null,"source":1}],"source":1,"value_type":"number"}],"installments":null,"winner_item_id":null,"catalog_listing":true,"discounts":null,"promotions":[],"inventory_id":"ASEH19655"},{"id":"MLA1431915980","title":"Neumático Pace Pc50 P 165/70r13 79 T","condition":"new","thumbnail_id":"847173-MLU74823533319_022024","catalog_product_id":"MLA19969892","listing_type_id":"gold_special","permalink":"https://www.mercadolibre.com.ar/neumatico-pace-pc50-p-16570r13-79-t/p/MLA19969892","buying_mode":"buy_it_now","site_id":"MLA","category_id":"MLA22195","domain_id":"MLA-AUTOMOTIVE_TIRES","thumbnail":"http://http2.mlstatic.com/D_847173-MLU74823533319_02 ...

# %%
url
# Out:
# 'https://api.mercadolibre.com//sites/MLA/search?category=5725'

# %%
#guardamos el resultado en un diccionario (json)
data = response.json()
#type(data) # dict
data
# Out:
# {'site_id': 'MLA',
#  'country_default_time_zone': 'GMT-03:00',
#  'paging': {'total': 5918283,
#   'primary_results': 1000,
#   'offset': 0,
#   'limit': 50},
#  'results': [{'id': 'MLA1277641650',
#    'title': 'Pack 4 Paños Microfibra Multiuso Limpieza Auto Hogar Oficina Color Varios',
#    'condition': 'new',
#    'thumbnail_id': '797432-MLA44041279363_112020',
#    'catalog_product_id': 'MLA20023033',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/pack-4-panos-microfibra-multiuso-limpieza-auto-hogar-oficina-color-varios/p/MLA20023033',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA424491',
#    'domain_id': 'MLA-CLEANING_CLOTHS',
#    'thumbnail': 'http://http2.mlstatic.com/D_797432-MLA44041279363_112020-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 1,
#    'price': 3830.4,
#    'original_price': 3830.4,
#    'sale_price': None,
#    'available_quantity': 200,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': False,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment', 'self_service_in'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2042-12-04T04:00:00.000Z',
#    'seller': {'id': 702150429, 'nickname': 'GLOBALNAVET'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '9067552',
#      'value_name': 'Laffitte',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '9067552',
#        'name': 'Laffitte',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '7792993337968',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '7792993337968',
#        'struct': None,
#        'source': 385122562515662}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'list'},
#     {'id': 'LENGTH',
#      'name': 'Largo',
#      'value_id': '7879371',
#      'value_name': '30 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 30, 'unit': 'cm'},
#      'values': [{'id': '7879371',
#        'name': '30 cm',
#        'struct': {'number': 30, 'unit': 'cm'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': None,
#      'value_name': 'AJ01H',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'AJ01H',
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'string'},
#     {'id': 'SALE_FORMAT',
#      'name': 'Formato de venta',
#      'value_id': '1359392',
#      'value_name': 'Pack',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1359392',
#        'name': 'Pack',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'UNITS_PER_PACK',
#      'name': 'Unidades por pack',
#      'value_id': '2726556',
#      'value_name': '4',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2726556', 'name': '4', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'number'},
#     {'id': 'UNITS_PER_PACKAGE',
#      'name': 'Unidades por envase',
#      'value_id': '7916708',
#      'value_name': '4',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '7916708', 'name': '4', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'number'}],
#    'installments': None,
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'ASEH19655'},
#   {'id': 'MLA1431915980',
#    'title': 'Neumático Pace Pc50 P 165/70r13 79 T',
#    'condition': 'new',
#    'thumbnail_id': '847173-MLU74823533319_022024',
#    'catalog_product_id': 'MLA19969892',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/neumatico-pace-pc50-p-16570r13-79-t/p/MLA19969892',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA22195',
#    'domain_id': 'MLA-AUTOMOTIVE_TIRES',
#    'thumbnail': 'http://http2.mlstatic.com/D_847173-MLU74823533319_022024-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 2,
#    'price': 92958.4,
#    'original_price': 92958.4,
#    'sale_price': None,
#    'available_quantity': 150,
#    'official_store_id': 51662,
#    'official_store_name': 'Pace',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2044-03-18T22:02:39.000Z',
#    'seller': {'id': 1394218845, 'nickname': 'PACEOFICIAL'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '3762998',
#      'value_name': 'Pace',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '3762998',
#        'name': 'Pace',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '6921109016409',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '6921109016409',
#        'struct': None,
#        'source': 385122562515662}],
#      'source': 4333789534002961,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6808261514773724}],
#      'source': 6808261514773724,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '437575',
#      'value_name': 'PC',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '437575',
#        'name': 'PC',
#        'struct': None,
#        'source': 4709228965570453}],
#      'source': 4709228965570453,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '13853151',
#      'value_name': 'PC50',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13853151',
#        'name': 'PC50',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '16 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 16, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '16 cm',
#        'struct': {'number': 16, 'unit': 'cm'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '6320 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 6320, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '6320 g',
#        'struct': {'number': 6320, 'unit': 'g'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'UNITS_PER_PACK',
#      'name': 'Unidades por pack',
#      'value_id': '2726554',
#      'value_name': '1',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2726554',
#        'name': '1',
#        'struct': None,
#        'source': 10000000000000000}],
#      'source': 10000000000000000,
#      'value_type': 'number'}],
#    'installments': {'quantity': 6,
#     'amount': 24621.58,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'KWTA48915'},
#   {'id': 'MLA1381143477',
#    'title': 'Alforjas Para Moto Impermeables Bolsos Laterales Extensibles Color Negro',
#    'condition': 'new',
#    'thumbnail_id': '819280-MLA73116995394_122023',
#    'catalog_product_id': 'MLA25391477',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/alforjas-para-moto-impermeables-bolsos-laterales-extensibles-color-negro/p/MLA25391477',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA434708',
#    'domain_id': 'MLA-MOTORCYCLE_SADDLEBAGS_AND_BACKPACKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_819280-MLA73116995394_122023-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 3,
#    'price': 39999,
#    'original_price': 39999,
#    'sale_price': None,
#    'available_quantity': 100,
#    'official_store_id': 52004,
#    'official_store_name': 'PHOENIX',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment', 'self_service_in', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2043-07-27T04:00:00.000Z',
#    'seller': {'id': 431643560, 'nickname': 'DINAMICSTOREOFICIAL'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '22049602',
#      'value_name': 'Alforja Nacional',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '22049602',
#        'name': 'Alforja Nacional',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '0763571798515',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '0763571798515',
#        'struct': None,
#        'source': 385122562515662}],
#      'source': 7571550481372610,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 3045741222775799}],
#      'source': 3045741222775799,
#      'value_type': 'list'},
#     {'id': 'LENGTH',
#      'name': 'Largo',
#      'value_id': '7175734',
#      'value_name': '20 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 20, 'unit': 'cm'},
#      'values': [{'id': '7175734',
#        'name': '20 cm',
#        'struct': {'number': 20, 'unit': 'cm'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '22049603',
#      'value_name': 'AJ-002',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '22049603',
#        'name': 'AJ-002',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '38.4 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 38.4, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '38.4 cm',
#        'struct': {'number': 38.4, 'unit': 'cm'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '2120 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 2120, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '2120 g',
#        'struct': {'number': 2120, 'unit': 'g'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'SALE_FORMAT',
#      'name': 'Formato de venta',
#      'value_id': '1359392',
#      'value_name': 'Pack',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1359392',
#        'name': 'Pack',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'UNITS_PER_PACK',
#      'name': 'Unidades por pack',
#      'value_id': '2726555',
#      'value_name': '2',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2726555', 'name': '2', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'number'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '11981133',
#      'value_name': '2.3 kg',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 2.3, 'unit': 'kg'},
#      'values': [{'id': '11981133',
#        'name': '2.3 kg',
#        'struct': {'unit': 'kg', 'number': 2.3},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 10594.4,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'AZAW70215'},
#   {'id': 'MLA851109741',
#    'title': 'Carcasa Llave Navaja Peugeot  2 Bot 307 308 C/portapila',
#    'condition': 'new',
#    'thumbnail_id': '800165-MLA71950611130_092023',
#    'catalog_product_id': None,
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-851109741-carcasa-llave-navaja-peugeot-2-bot-307-308-cportapila-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA373345',
#    'domain_id': 'MLA-VEHICLE_IGNITION_SWITCHES',
#    'thumbnail': 'http://http2.mlstatic.com/D_800165-MLA71950611130_092023-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 4,
#    'price': 5780.39,
#    'original_price': 5780.39,
#    'sale_price': None,
#    'available_quantity': 50,
#    'official_store_id': 3272,
#    'official_store_name': 'Keyfad',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': False,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2040-04-18T04:00:00.000Z',
#    'seller': {'id': 435859328, 'nickname': 'KEYFAD'},
#    'attributes': [{'id': 'UNITS_PER_PACKAGE',
#      'name': 'Unidades por envase',
#      'value_id': None,
#      'value_name': '1',
#      'attribute_group_id': '',
#      'attribute_group_name': '',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '1',
#        'struct': None,
#        'source': 2302378583965437}],
#      'source': 2302378583965437,
#      'value_type': 'integer'},
#     {'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '23188372',
#      'value_name': 'Keyfad',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '23188372',
#        'name': 'Keyfad',
#        'struct': None,
#        'source': 2302378583965437}],
#      'source': 2302378583965437,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 2302378583965437}],
#      'source': 2302378583965437,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'list'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '3 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 3, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '3 cm',
#        'struct': {'number': 3, 'unit': 'cm'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '40 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 40, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '40 g',
#        'struct': {'number': 40, 'unit': 'g'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 1531.03,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'VFWO83581'},
#   {'id': 'MLA1214441181',
#    'title': 'Aspiradora Para Auto Y Hogar Yelmo As-3240 Recargable Usb',
#    'condition': 'new',
#    'thumbnail_id': '927490-MLU74110426058_012024',
#    'catalog_product_id': 'MLA19719361',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/aspiradora-para-auto-y-hogar-yelmo-as-3240-recargable-usb/p/MLA19719361',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA86840',
#    'domain_id': 'MLA-VACUUM_AND_STEAM_CLEANERS',
#    'thumbnail': 'http://http2.mlstatic.com/D_927490-MLU74110426058_012024-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 5,
#    'price': 54900,
#    'original_price': 54900,
#    'sale_price': None,
#    'available_quantity': 50,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment', 'self_service_in', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2042-10-21T04:00:00.000Z',
#    'seller': {'id': 216203805, 'nickname': 'HYT.COM.AR'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '255',
#      'value_name': 'Yelmo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '255', 'name': 'Yelmo', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '7790368297169',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '7790368297169',
#        'struct': None,
#        'source': 385122562515662}],
#      'source': 6808261514773724,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6808261514773724}],
#      'source': 6808261514773724,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '13364584',
#      'value_name': 'AS-3240',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13364584',
#        'name': 'AS-3240',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '40.4 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 40.4, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '40.4 cm',
#        'struct': {'unit': 'cm', 'number': 40.4},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '860 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 860, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '860 g',
#        'struct': {'number': 860, 'unit': 'g'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'POWER',
#      'name': 'Potencia',
#      'value_id': '357784',
#      'value_name': '80 W',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 80, 'unit': 'W'},
#      'values': [{'id': '357784',
#        'name': '80 W',
#        'struct': {'unit': 'W', 'number': 80},
#        'source': 4709228965570453}],
#      'source': 4709228965570453,
#      'value_type': 'number_unit'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '8068573',
#      'value_name': '0.94 kg',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 0.94, 'unit': 'kg'},
#      'values': [{'id': '8068573',
#        'name': '0.94 kg',
#        'struct': {'number': 0.94, 'unit': 'kg'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 14541.18,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'GUAW60959'},
#   {'id': 'MLA1145029073',
#    'title': 'Stereo Bluetooth Auto Car Estereo Usb Mp3 Fm Smart Tech Jsd-520',
#    'condition': 'new',
#    'thumbnail_id': '720460-MLU72930552533_112023',
#    'catalog_product_id': 'MLA19148883',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/stereo-bluetooth-auto-car-estereo-usb-mp3-fm-smart-tech-jsd-520/p/MLA19148883',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA6867',
#    'domain_id': 'MLA-VEHICLE_STEREOS',
#    'thumbnail': 'http://http2.mlstatic.com/D_720460-MLU72930552533_112023-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 6,
#    'price': 27499,
#    'original_price': 27499,
#    'sale_price': None,
#    'available_quantity': 250,
#    'official_store_id': 3038,
#    'official_store_name': 'Proshop',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment',
#      'fs_threshold_mla_change_feb2021',
#      'self_service_in',
#      'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2042-10-14T08:17:23.000Z',
#    'seller': {'id': 139673546, 'nickname': 'NETSHOP_1000'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca del stereo',
#      'value_id': '410971',
#      'value_name': 'Smart Tech',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '410971',
#        'name': 'Smart Tech',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '7798339072265',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '7798339072265',
#        'struct': None,
#        'source': 385122562515662}],
#      'source': 3376461333454861,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1572}],
#      'source': 1572,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo del stereo',
#      'value_id': '7959045',
#      'value_name': 'JSD-520',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '7959045',
#        'name': 'JSD-520',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'}],
#    'installments': {'quantity': 6,
#     'amount': 7283.57,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'LNCB25775'},
#   {'id': 'MLA1432301698',
#    'title': 'Pace Pc50 175/65r14 - 82 - H - P - 1 - 1',
#    'condition': 'new',
#    'thumbnail_id': '692031-MLU74693469446_022024',
#    'catalog_product_id': 'MLA21094023',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/pace-pc50-17565r14-82-h-p-1-1/p/MLA21094023',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA22195',
#    'domain_id': 'MLA-AUTOMOTIVE_TIRES',
#    'thumbnail': 'http://http2.mlstatic.com/D_692031-MLU74693469446_022024-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 7,
#    'price': 104389,
#    'original_price': 104389,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': 51662,
#    'official_store_name': 'Pace',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2044-03-17T16:42:15.000Z',
#    'seller': {'id': 1394218845, 'nickname': 'PACEOFICIAL'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '3762998',
#      'value_name': 'Pace',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '3762998',
#        'name': 'Pace',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '6921109016478',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '6921109016478',
#        'struct': None,
#        'source': 385122562515662}],
#      'source': 385122562515662,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6808261514773724}],
#      'source': 6808261514773724,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '26876734',
#      'value_name': 'PC50',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '26876734',
#        'name': 'PC50',
#        'struct': None,
#        'source': 4709228965570453}],
#      'source': 4709228965570453,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '13853151',
#      'value_name': 'PC50',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13853151',
#        'name': 'PC50',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '17 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 17, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '17 cm',
#        'struct': {'unit': 'cm', 'number': 17},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '6840 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 6840, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '6840 g',
#        'struct': {'number': 6840, 'unit': 'g'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'UNITS_PER_PACK',
#      'name': 'Unidades por pack',
#      'value_id': '2726554',
#      'value_name': '1',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2726554',
#        'name': '1',
#        'struct': None,
#        'source': 10000000000000000}],
#      'source': 10000000000000000,
#      'value_type': 'number'}],
#    'installments': {'quantity': 6,
#     'amount': 27649.17,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'YYXW47639'},
#   {'id': 'MLA1541006222',
#    'title': 'Intercomunicador Moto Ejeas V6pro Bluetooth 1200mts 6 Pilotos Usbc',
#    'condition': 'new',
#    'thumbnail_id': '712351-MLU74215842869_012024',
#    'catalog_product_id': 'MLA24598236',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/intercomunicador-moto-ejeas-v6pro-bluetooth-1200mts-6-pilotos-usbc/p/MLA24598236',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA379647',
#    'domain_id': 'MLA-MOTORCYCLE_INTERCOMMUNICATORS',
#    'thumbnail': 'http://http2.mlstatic.com/D_712351-MLU74215842869_012024-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 8,
#    'price': 65899,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 150,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment', 'self_service_in', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2043-10-14T04:00:00.000Z',
#    'seller': {'id': 22779161, 'nickname': 'VOIP EXPERTS'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '18700927',
#      'value_name': 'Ejeas',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '18700927',
#        'name': 'Ejeas',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '791658500454',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '791658500454',
#        'struct': None,
#        'source': 385122562515662}],
#      'source': 385122562515662,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 3045741222775799}],
#      'source': 3045741222775799,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '20965138',
#      'value_name': 'V6-PRO-INTERCOM',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '20965138',
#        'name': 'V6-PRO-INTERCOM',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '15.8 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 15.8, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '15.8 cm',
#        'struct': {'number': 15.8, 'unit': 'cm'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '240 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 240, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '240 g',
#        'struct': {'number': 240, 'unit': 'g'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 17454.45,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'MCVT66267'},
#   {'id': 'MLA1288014161',
#    'title': 'Limpia Inyectores Nafta Fuel System Cleaner Pro-line 1870',
#    'condition': 'new',
#    'thumbnail_id': '889171-MLA53006477818_122022',
#    'catalog_product_id': None,
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1288014161-limpia-inyectores-nafta-fuel-system-cleaner-pro-line-1870-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA61201',
#    'domain_id': 'MLA-VEHICLE_FUEL_INJECTORS',
#    'thumbnail': 'http://http2.mlstatic.com/D_889171-MLA53006477818_122022-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 9,
#    'price': 26679.08,
#    'original_price': 28999,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2042-12-17T04:00:00.000Z',
#    'seller': {'id': 241356983, 'nickname': 'RAISOL REPUESTOS'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '2786975',
#      'value_name': 'Liqui Moly',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2786975',
#        'name': 'Liqui Moly',
#        'struct': None,
#        'source': 7092}],
#      'source': 7092,
#      'value_type': 'string'},
#     {'id': 'FUEL_TYPE',
#      'name': 'Tipo de combustible',
#      'value_id': '64364',
#      'value_name': 'Nafta',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '64364',
#        'name': 'Nafta',
#        'struct': None,
#        'source': 3045741222775799}],
#      'source': 3045741222775799,
#      'value_type': 'list'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 3045741222775799}],
#      'source': 3045741222775799,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': None,
#      'value_name': 'PRO LINE',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'PRO LINE',
#        'struct': None,
#        'source': 3045741222775799}],
#      'source': 3045741222775799,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '20.4 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 20.4, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '20.4 cm',
#        'struct': {'unit': 'cm', 'number': 20.4},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '360 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 360, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '360 g',
#        'struct': {'unit': 'g', 'number': 360},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 7066.4,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'PAGC75951'},
#   {'id': 'MLA1374996363',
#    'title': 'Aceite Para Motor Valvoline Semi-sintético 10w-40 Para Autos, Pickups & Suv De 1 Unidad',
#    'condition': 'new',
#    'thumbnail_id': '964193-MLU74245577815_012024',
#    'catalog_product_id': 'MLA19628368',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/aceite-para-motor-valvoline-semi-sintetico-10w-40-para-autos-pickups-suv-de-1-unidad/p/MLA19628368',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA375007',
#    'domain_id': 'MLA-ENGINE_OILS',
#    'thumbnail': 'http://http2.mlstatic.com/D_964193-MLU74245577815_012024-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 10,
#    'price': 30900,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'xd_drop_off',
#     'mode': 'me2',
#     'tags': ['self_service_in', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2043-06-23T04:00:00.000Z',
#    'seller': {'id': 549639091, 'nickname': 'LUBRI_ARTIGAS'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '2786974',
#      'value_name': 'Valvoline',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2786974',
#        'name': 'Valvoline',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'DETAILED_MODEL',
#      'name': 'Modelo detallado',
#      'value_id': '20176272',
#      'value_name': 'Premium Protection',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '20176272',
#        'name': 'Premium Protection',
#        'struct': None,
#        'source': 4709228965570453}],
#      'source': 4709228965570453,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 4060709329251625}],
#      'source': 4060709329251625,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6808261514773724}],
#      'source': 6808261514773724,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '13112056',
#      'value_name': 'Premium Protection',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13112056',
#        'name': 'Premium Protection',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'NET_VOLUME',
#      'name': 'Volumen neto',
#      'value_id': '18614246',
#      'value_name': '3.784 L',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 3.784, 'unit': 'L'},
#      'values': [{'id': '18614246',
#        'name': '3.784 L',
#        'struct': {'number': 3.784, 'unit': 'L'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'SALE_FORMAT',
#      'name': 'Formato de venta',
#      'value_id': '1359391',
#      'value_name': 'Unidad',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1359391',
#        'name': 'Unidad',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'UNITS_PER_PACK',
#      'name': 'Unidades por pack',
#      'value_id': '2726554',
#      'value_name': '1',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2726554', 'name': '1', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'number'},
#     {'id': 'UNIT_VOLUME',
#      'name': 'Volumen de la unidad',
#      'value_id': '18614247',
#      'value_name': '3.784 L',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 3.784, 'unit': 'L'},
#      'values': [{'id': '18614247',
#        'name': '3.784 L',
#        'struct': {'number': 3.784, 'unit': 'L'},
#        'source': 4709228965570453}],
#      'source': 4709228965570453,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 8184.38,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1416712261',
#    'title': 'Aceite Para Motor Total Semi-sintético 10w-40 Para Autos, Pickups & Suvs De 1 Unidad X 4l',
#    'condition': 'new',
#    'thumbnail_id': '840750-MLA54719967937_032023',
#    'catalog_product_id': 'MLA22386055',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/aceite-para-motor-total-semi-sintetico-10w-40-para-autos-pickups-suvs-de-1-unidad-x-4l/p/MLA22386055',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA429228',
#    'domain_id': 'MLA-ENGINE_OILS',
#    'thumbnail': 'http://http2.mlstatic.com/D_840750-MLA54719967937_032023-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 11,
#    'price': 33748.16,
#    'original_price': 40176.39,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2044-03-16T04:00:00.000Z',
#    'seller': {'id': 614362681, 'nickname': 'AVANT SA'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '2706606',
#      'value_name': 'Total',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2706606',
#        'name': 'Total',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'DETAILED_MODEL',
#      'name': 'Modelo detallado',
#      'value_id': '14788204',
#      'value_name': 'quartz',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '14788204',
#        'name': 'quartz',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6808261514773724}],
#      'source': 6808261514773724,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '17735744',
#      'value_name': 'Quartz 7000',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '17735744',
#        'name': 'Quartz 7000',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'NET_VOLUME',
#      'name': 'Volumen neto',
#      'value_id': '4890408',
#      'value_name': '4 L',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 4, 'unit': 'L'},
#      'values': [{'id': '4890408',
#        'name': '4 L',
#        'struct': {'unit': 'L', 'number': 4},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '10.4 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 10.4, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '10.4 cm',
#        'struct': {'number': 10.4, 'unit': 'cm'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '3680 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 3680, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '3680 g',
#        'struct': {'unit': 'g', 'number': 3680},
# ...
#     {'id': '2480348', 'name': 'Bahco', 'results': 1160},
#     {'id': '24800808', 'name': 'Innovations', 'results': 1160},
#     {'id': '24718847', 'name': 'BRENTA', 'results': 1160},
#     {'id': '2469692', 'name': 'Cfmoto', 'results': 1160},
#     {'id': '2451032', 'name': 'Motorcraft', 'results': 1160},
#     {'id': '243232', 'name': 'Nitro', 'results': 1160},
#     {'id': '2430203', 'name': 'NTK', 'results': 1160},
#     {'id': '2426343', 'name': 'Dinax', 'results': 1160},
#     {'id': '24158134', 'name': 'Euga', 'results': 1160},
#     {'id': '2413156', 'name': 'Sierra', 'results': 1160},
#     {'id': '24050', 'name': 'Cadillac', 'results': 1160},
#     {'id': '2379212', 'name': 'Riffel', 'results': 1160},
#     {'id': '23745899', 'name': 'Traxion', 'results': 1160},
#     {'id': '2368601', 'name': 'Givi', 'results': 1160},
#     {'id': '23461', 'name': 'Diesel', 'results': 1160},
#     {'id': '233507', 'name': 'Aplus', 'results': 1160},
#     {'id': '23132', 'name': 'Puma', 'results': 1160},
#     {'id': '2299403', 'name': 'Hard Power', 'results': 1160},
#     {'id': '22882832', 'name': 'Etma', 'results': 1160},
#     {'id': '22882829', 'name': 'Eristic', 'results': 1160},
#     {'id': '22805988', 'name': 'Armetal', 'results': 1160},
#     {'id': '22680080', 'name': 'Motexo', 'results': 1160},
#     {'id': '22680078', 'name': 'MohEr', 'results': 1160},
#     {'id': '22680073', 'name': 'Mikuni', 'results': 1160},
#     {'id': '22680072', 'name': 'Meyle', 'results': 1160},
#     {'id': '22680069', 'name': 'Metalivia', 'results': 1160},
#     {'id': '22445536', 'name': 'Univel', 'results': 1160},
#     {'id': '2188859', 'name': 'Mateo', 'results': 1160},
#     {'id': '21881261', 'name': 'Proteam', 'results': 1160},
#     {'id': '21552370', 'name': 'BMB', 'results': 1160},
#     {'id': '21246590', 'name': 'Norwing', 'results': 1160},
#     {'id': '2122439', 'name': 'STH', 'results': 1160},
#     {'id': '2116770', 'name': 'Cummins', 'results': 1160},
#     {'id': '20969790', 'name': 'Baoli', 'results': 1160},
#     {'id': '2082129', 'name': 'Juki', 'results': 1160},
#     {'id': '20634516', 'name': 'Twin Air', 'results': 1160},
#     {'id': '20634515', 'name': 'Vernet', 'results': 1160},
#     {'id': '20634513', 'name': 'Ron Bay', 'results': 1160},
#     {'id': '20547136', 'name': 'Royal Pads', 'results': 1160},
#     {'id': '20445652', 'name': 'Truckliner', 'results': 1160},
#     {'id': '20445636', 'name': 'Fri-ma', 'results': 1160},
#     {'id': '20445635', 'name': 'Highway Star', 'results': 1160},
#     {'id': '20445630', 'name': 'Plasti Dip', 'results': 1160},
#     {'id': '20445629', 'name': 'BorgWarner', 'results': 1160},
#     {'id': '20445626', 'name': 'Coolxpert', 'results': 1160},
#     {'id': '20445624', 'name': 'Prometal', 'results': 1160},
#     {'id': '20445586', 'name': 'Protaper', 'results': 1160},
#     {'id': '20445583', 'name': 'Catiimoto', 'results': 1160},
#     {'id': '20445446', 'name': 'GEA', 'results': 1160},
#     {'id': '20445167', 'name': 'KOK', 'results': 1160},
#     {'id': '20416054', 'name': 'Genpar', 'results': 1160},
#     {'id': '20415928', 'name': 'Pro-X', 'results': 1160},
#     {'id': '20013529', 'name': 'Helmet', 'results': 1160},
#     {'id': '19894949', 'name': 'Gulf Oil', 'results': 1160},
#     {'id': '19831147', 'name': 'Gate', 'results': 1160},
#     {'id': '19815666', 'name': 'A Y D', 'results': 1160},
#     {'id': '194', 'name': 'Atma', 'results': 1160},
#     {'id': '18951311', 'name': 'HID', 'results': 1160},
#     {'id': '18701041', 'name': 'Baratec', 'results': 1160},
#     {'id': '18701027', 'name': 'Vaprén', 'results': 1160},
#     {'id': '18700989', 'name': 'Fadecya', 'results': 1160},
#     {'id': '18673757', 'name': 'Marflo', 'results': 1160},
#     {'id': '18557162', 'name': 'GMC', 'results': 1160},
#     {'id': '18469064', 'name': 'Italy', 'results': 1160},
#     {'id': '18322', 'name': 'Alfa', 'results': 1160},
#     {'id': '18284841', 'name': 'Autopolish', 'results': 1160},
#     {'id': '17891736', 'name': 'DPA', 'results': 1160},
#     {'id': '17861953', 'name': 'OHC', 'results': 1160},
#     {'id': '17782371', 'name': "Meguiar's", 'results': 1160},
#     {'id': '177584', 'name': 'Stanley', 'results': 1160},
#     {'id': '17643525', 'name': 'Simil', 'results': 1160},
#     {'id': '17621777', 'name': 'Chevrolet Gm', 'results': 1160},
#     {'id': '17513556', 'name': 'DBH', 'results': 1160},
#     {'id': '17471595', 'name': 'RW', 'results': 1160},
#     {'id': '17196650', 'name': 'Acessórios Chevrolet', 'results': 1160},
#     {'id': '17072388', 'name': 'GKG', 'results': 1160},
#     {'id': '17024619', 'name': 'Top Safe', 'results': 1160},
#     {'id': '17005562', 'name': 'BRK', 'results': 1160},
#     {'id': '16954541', 'name': 'RDS', 'results': 1160},
#     {'id': '16913340', 'name': 'Aulitools', 'results': 1160},
#     {'id': '168297', 'name': 'Zetta', 'results': 1160},
#     {'id': '16501264', 'name': 'DH', 'results': 1160},
#     {'id': '16399343', 'name': 'FB', 'results': 1160},
#     {'id': '16365266', 'name': 'Rapikits', 'results': 1160},
#     {'id': '16346827', 'name': 'AF', 'results': 1160},
#     {'id': '16317152', 'name': 'Legitimo', 'results': 1160},
#     {'id': '161314', 'name': 'Bomber', 'results': 1160},
#     {'id': '16037', 'name': 'Audio-Technica', 'results': 1160},
#     {'id': '16036396', 'name': 'Alternativa', 'results': 1160},
#     {'id': '16018973', 'name': 'Led', 'results': 1160},
#     {'id': '16003420', 'name': 'Connects', 'results': 1160},
#     {'id': '159433', 'name': 'Nasa', 'results': 1160},
#     {'id': '15925339', 'name': 'Fercol', 'results': 1160},
#     {'id': '15784', 'name': 'Kappa', 'results': 1160},
#     {'id': '15413954', 'name': 'TF', 'results': 1160},
#     {'id': '15345078', 'name': 'Ceramic', 'results': 1160},
#     {'id': '15147869', 'name': 'High Tech', 'results': 1160},
#     {'id': '15024686', 'name': 'RR', 'results': 1160},
#     {'id': '15019072', 'name': 'Linares', 'results': 1160},
#     {'id': '14920524', 'name': 'Y & Z', 'results': 1160},
#     {'id': '14802787', 'name': 'FNX', 'results': 1160},
#     {'id': '14750768', 'name': 'Jetta', 'results': 1160},
#     {'id': '14684', 'name': 'Harley-Davidson', 'results': 1160},
#     {'id': '14422721', 'name': 'Argentina', 'results': 1160},
#     {'id': '14365270', 'name': 'Ibiza', 'results': 1160},
#     {'id': '14292358', 'name': 'BGM', 'results': 1160},
#     {'id': '14223790', 'name': 'G', 'results': 1160},
#     {'id': '13947412', 'name': 'Lezaya', 'results': 1160},
#     {'id': '13833068', 'name': 'Genérico Importado', 'results': 1160},
#     {'id': '13795926', 'name': 'Rama', 'results': 1160},
#     {'id': '13714250', 'name': 'SS', 'results': 1160},
#     {'id': '13660693', 'name': 'TDC', 'results': 1160},
#     {'id': '13618274', 'name': 'Korea', 'results': 1160},
#     {'id': '13497908', 'name': 'Bosh', 'results': 1160},
#     {'id': '13396335', 'name': 'Ternnova', 'results': 1160},
#     {'id': '13378844', 'name': 'FLEXINTER', 'results': 1160},
#     {'id': '13371556', 'name': 'China', 'results': 1160},
#     {'id': '13325071', 'name': 'K78', 'results': 1160},
#     {'id': '13079618', 'name': 'Iron', 'results': 1160},
#     {'id': '13019654', 'name': 'Vileda', 'results': 1160},
#     {'id': '12918574', 'name': 'AC Estampas', 'results': 1160},
#     {'id': '12860275', 'name': 'JG', 'results': 1160},
#     {'id': '12324303', 'name': 'Vika', 'results': 1160},
#     {'id': '12272945', 'name': 'ACParts', 'results': 1160},
#     {'id': '12239658', 'name': 'Auto Drive', 'results': 1160},
#     {'id': '12234779', 'name': 'Meyro', 'results': 1160},
#     {'id': '12228267', 'name': 'Vini', 'results': 1160},
#     {'id': '1218165', 'name': 'Keeway', 'results': 1160},
#     {'id': '12179153', 'name': 'Schaeffler', 'results': 1160},
#     {'id': '12179081', 'name': 'Loma Plast', 'results': 1160},
#     {'id': '12084367', 'name': 'FTE', 'results': 1160},
#     {'id': '12072419', 'name': 'FAG', 'results': 1160},
#     {'id': '12072231', 'name': 'Vedamotors', 'results': 1160},
#     {'id': '12072223', 'name': 'Ferodo', 'results': 1160},
#     {'id': '12047947', 'name': 'NPR', 'results': 1160},
#     {'id': '12047823', 'name': 'QP', 'results': 1160},
#     {'id': '12046562', 'name': 'Sealed Power', 'results': 1160},
#     {'id': '11813839', 'name': 'Doblett', 'results': 1160},
#     {'id': '116918', 'name': "O'Neal", 'results': 1160},
#     {'id': '1148085', 'name': 'HT', 'results': 1160},
#     {'id': '1138', 'name': 'Mitsubishi', 'results': 1160},
#     {'id': '11278702', 'name': 'GF', 'results': 1160},
#     {'id': '1126958', 'name': 'Maverick', 'results': 1160},
#     {'id': '11211016', 'name': 'RGU', 'results': 1160},
#     {'id': '11211015', 'name': 'RGU PRO', 'results': 1160},
#     {'id': '11134183', 'name': 'Nac', 'results': 1160},
#     {'id': '11126245', 'name': 'Next', 'results': 1160},
#     {'id': '11046157', 'name': 'Basso', 'results': 1160},
#     {'id': '11022700', 'name': 'Santa Lúcia', 'results': 1160},
#     {'id': '108426', 'name': 'Brava', 'results': 1160},
#     {'id': '10724451', 'name': 'AJE', 'results': 1160},
#     {'id': '10718698', 'name': 'Indebras', 'results': 1160},
#     {'id': '10470343', 'name': 'Ipone', 'results': 1160},
#     {'id': '10345545', 'name': 'CTR', 'results': 1160},
#     {'id': '10098278', 'name': 'AIRTEX', 'results': 1160},
#     {'id': '100514', 'name': 'Parker', 'results': 1160}]},
#   {'id': 'ITEM_CONDITION',
#    'name': 'Condición',
#    'type': 'STRING',
#    'values': [{'id': '2230284', 'name': 'Nuevo', 'results': 5769840},
#     {'id': '2230581', 'name': 'Usado', 'results': 134560},
#     {'id': '2230582', 'name': 'Reacondicionado', 'results': 2320}]},
#   {'id': 'official_store',
#    'name': 'Tiendas oficiales',
#    'type': 'text',
#    'values': [{'id': 'all',
#      'name': 'Todas las tiendas oficiales',
#      'results': 304313},
#     {'id': '3272', 'name': 'Keyfad', 'results': 1187},
#     {'id': '52004', 'name': 'PHOENIX', 'results': 3},
#     {'id': '2714', 'name': 'Chevrolet', 'results': 39074},
#     {'id': '2515', 'name': 'Dinamic Store', 'results': 1186},
#     {'id': '51662', 'name': 'Pace', 'results': 2},
#     {'id': '2981', 'name': 'SportMotors Argentina', 'results': 4737},
#     {'id': '255', 'name': 'Alarmas X28', 'results': 1185},
#     {'id': '997', 'name': 'Baofeng', 'results': 1185},
#     {'id': '2132', 'name': 'EscobarFord', 'results': 1},
#     {'id': '224', 'name': 'Fate', 'results': 1},
#     {'id': '2537', 'name': 'Fercol', 'results': 1},
#     {'id': '2839', 'name': 'LIBERCAM', 'results': 1},
#     {'id': '2893', 'name': 'Smart Tech', 'results': 1},
#     {'id': '3038', 'name': 'Proshop', 'results': 1},
#     {'id': '3215', 'name': 'Hallbar', 'results': 1},
#     {'id': '3220', 'name': 'Mercado Libre Autopartes', 'results': 1},
#     {'id': '62672', 'name': 'Norwing', 'results': 1},
#     {'id': '945', 'name': 'Gadnic', 'results': 1}]},
#   {'id': 'product',
#    'name': 'Producto',
#    'type': 'text',
#    'values': [{'id': 'MLA10292230',
#      'name': 'Casco para moto integral Hawk RS1  negro brillante talle XL ',
#      'results': 1},
#     {'id': 'MLA10810103', 'name': 'X-28 M20', 'results': 1},
#     {'id': 'MLA11386906',
#      'name': 'Casco para moto integral Halcon H57  rojo talle S ',
#      'results': 1},
#     {'id': 'MLA11434943',
#      'name': 'Estéreo para auto Crown Mustang DMR-3000BT con USB, bluetooth y lector de tarjeta SD',
#      'results': 1},
#     {'id': 'MLA14786091',
#      'name': 'Fate Maxisport 2 175/65R14 - 82 - T - 1 - 1',
#      'results': 1},
#     {'id': 'MLA14792989',
#      'name': 'Neumático Fate Maxisport 2 165/70R13 79 T',
#      'results': 1},
#     {'id': 'MLA14793781',
#      'name': 'Neumático Bridgestone Turanza ER300 205/55R16 91V',
#      'results': 1},
#     {'id': 'MLA14850247',
#      'name': 'Neumático Bridgestone Turanza ER30 P 195/55R15 85 H',
#      'results': 1},
#     {'id': 'MLA15009257',
#      'name': 'Neumático Firestone Firehawk 900 P 205/55R16 91 V',
#      'results': 1},
#     {'id': 'MLA15014091',
#      'name': 'Bridgestone Turanza T001 215/50R17 - 91 - V - P - 1 - 1',
#      'results': 1},
#     {'id': 'MLA15014908',
#      'name': 'Neumático Firestone Destination A/T 205/65R15 94 T',
#      'results': 1},
#     {'id': 'MLA15018045',
#      'name': 'Neumático Pirelli Formula Energy P 175/65R14 82 T',
#      'results': 1},
#     {'id': 'MLA15075050',
#      'name': 'Audio Technica At2020 Microfono Condenser',
#      'results': 1},
#     {'id': 'MLA15148934',
#      'name': 'Neumático Firestone F-Series F-700 175/65R14 82 T',
#      'results': 1},
#     {'id': 'MLA15379937',
#      'name': 'Casco para moto integral Halcon H5 Kids  rosa talle XS ',
#      'results': 1},
#     {'id': 'MLA15451164',
#      'name': 'Estéreo para auto Philco CSP810BT con USB, bluetooth y lector de tarjeta SD',
#      'results': 1},
#     {'id': 'MLA15476585',
#      'name': 'Neumático Bridgestone Dueler A/T 693 265/65R17 112 S',
#      'results': 1},
#     {'id': 'MLA15736652',
#      'name': 'Cubierta trasero para moto Michelin Pilot Street sin cámara de 130/70-17 S 62 x 1 unidad',
#      'results': 1},
#     {'id': 'MLA15737754',
#      'name': 'Cubierta trasera para moto Pirelli Super City para uso con cámara de 90/90-18 P 51 x 1 unidad',
#      'results': 1},
#     {'id': 'MLA15738512',
#      'name': 'Compresor de aire mini a batería portátil Iael VA-044 12V gris',
#      'results': 1},
#     {'id': 'MLA16006708',
#      'name': 'Cubierta Trasera Celimo HD-565 uso sin cámara de 140/60 R17 S 63 x 1 unidad',
#      'results': 1},
#     {'id': 'MLA16025590',
#      'name': 'Neumático Firestone Multihawk P 175/65R14 86 T',
#      'results': 1},
#     {'id': 'MLA16139274',
#      'name': 'Aspiradora Industrial Pektra 15 L Polvo Liquido Acero Inox Color Plateado/Negro/Rojo',
#      'results': 1}]}],
#  'pdp_tracking': {'group': False,
#   'product_info': [{'id': 'MLA20023033', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19969892', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA25391477', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19719361', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19148883', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA21094023', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA24598236', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19628368', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA22386055', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA23854006', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA15014091', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA27657395', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA10292230', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA27469395', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA15476585', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA23902807', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19667474', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19667445', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA14850247', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19667455', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19690494', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA11434943', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA22388367', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA15009257', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA10810103', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA28265100', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA28143181', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19581759', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA15018045', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA25586908', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19918217', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19628361', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA21236572', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA18738800', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA34353963', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA23880927', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA15736652', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA15014908', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19612778', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19667466', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA6261296', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA24448843', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA15148934', 'score': 1, 'status': 'shown'}]}}

# %%
#Vamos a analizar los precios de los ítems.
precios = []
# buscamos en los resultados para extraer los precios
for item in data['results']:
    precios.append(item['price'])
# ahora creamos un dataFrame con los precios
df_precios = pd.DataFrame(precios, columns=['Precio'])

# definimos nuestras variables que calculan el precio promedio y asi analizar el resultado
precio_promedio = df_precios['Precio'].mean()
print("precio promedio:", precio_promedio)
#vemos que el precio promedio de accesorios para vehiculos es de 71124.1136
# Out:
# precio promedio: 71124.1136

# %% [markdown]
# ### Parte B

# %% [markdown]
# #### Ejercicio 5
# De la página de noticias del [diario La Nación](https://www.lanacion.com.ar/), utilicen herramientas de web scraping para obtener los links de las noticias de la portada. Guarden los links obtenidos en un dataframe y expórtenlo a un archivo de excel.
#
# Nota 1: es posible que logren obtener los links a las noticias sin el dominio: "https://www.lanacion.com.ar/". De ser así, concatenen el dominio a la ruta del link obtenido, tal que se obtenga un link al que se pueda acceder. Es decir, que las cadenas de caracteres finales tendrán la forma: https://www.lanacion.com.ar/*texto_obtenido*)
#
# Nota 2: junto con su entrega, adjunten una captura de la página de noticias al momento de correr su código. Eso servirá al momento de la corrección para verificar que los links obtenidos hacen referencia a las noticias de ese día y hora.

# %%
import requests #html requestor
from bs4 import BeautifulSoup #html parser
import pandas as pd #dataframe manipulator

# %%
url = "https://www.lanacion.com.ar/"

r = requests.get(url) #traigo el contenido del html
contenido = r.content

soup = BeautifulSoup(contenido, "html.parser")
soup
# Out:
# <!DOCTYPE html>
# <html lang="es"><head><meta charset="utf-8"/><meta content="width=device-width,initial-scale=1.0,minimum-scale=0.5,maximum-scale=5.0,user-scalable=yes" name="viewport"/><meta content="#ffffff" name="theme-color"/><title>Últimas noticias de Argentina y el mundo - LA NACION</title><link as="image" fetchpriority="high" href="https://www.lanacion.com.ar/resizer/v2/estela-de-carlotto-critico-a-javier-milei-y-pidio-NWCVBDRVSRFRBNQJVSMCVDIFSM.JPG?auth=509cb169ee007d6b0deee39db9ce9fddea2d0b45dd844db1093792ea088ade5b&amp;width=488&amp;height=325&amp;quality=70&amp;smart=true" media="(min-width: 768px)" rel="preload"/><link as="image" fetchpriority="high" href="https://www.lanacion.com.ar/resizer/v2/estela-de-carlotto-critico-a-javier-milei-y-pidio-NWCVBDRVSRFRBNQJVSMCVDIFSM.JPG?auth=509cb169ee007d6b0deee39db9ce9fddea2d0b45dd844db1093792ea088ade5b&amp;width=420&amp;height=280&amp;quality=70&amp;smart=true" media="(max-width: 767px)" rel="preload"/><style>
# @font-face {font-family:'Prumo';src:url('/pf/resources/fonts/prumo/Prumo-LNVF.woff2?d=1493') format('woff2-variations'); font-weight: 90; font-display: swap;}
# @font-face {font-family:'Prumo Italic';src:url('/pf/resources/fonts/prumo/Prumo-ItalicLNVF.woff2?d=1493') format('woff2-variations'); font-weight: 90; font-display: swap;}
# .--prumo{font-family:"Prumo","Georgia"}.--font-primary{font-family:"Prumo","Georgia"}.row{display:flex;flex-wrap:wrap;width:100%}[class*=col-]{width:100%;position:relative}.col{flex-basis:0%;flex-grow:1;max-width:100%}.col-1{flex:0 0 8.3333333333%;max-width:8.3333333333%}.col-2{flex:0 0 16.6666666667%;max-width:16.6666666667%}.col-3{flex:0 0 25%;max-width:25%}.col-4{flex:0 0 33.3333333333%;max-width:33.3333333333%}.col-5{flex:0 0 41.6666666667%;max-width:41.6666666667%}.col-6{flex:0 0 50%;max-width:50%}.col-7{flex:0 0 58.3333333333%;max-width:58.3333333333%}.col-8{flex:0 0 66.6666666667%;max-width:66.6666666667%}.col-9{flex:0 0 75%;max-width:75%}.col-10{flex:0 0 83.3333333333%;max-width:83.3333333333%}.col-11{flex:0 0 91.6666666667%;max-width:91.6666666667%}.col-12{flex:0 0 100%;max-width:100%}@media (min-width:768px){.col-tablet{flex-basis:0%;flex-grow:1;max-width:100%}.col-tablet-1{flex:0 0 8.3333333333%;max-width:8.3333333333%}.col-tablet-2{flex:0 0 16.6666666667%;max-width:16.6666666667%}.col-tablet-3{flex:0 0 25%;max-width:25%}.col-tablet-4{flex:0 0 33.3333333333%;max-width:33.3333333333%}.col-tablet-5{flex:0 0 41.6666666667%;max-width:41.6666666667%}.col-tablet-6{flex:0 0 50%;max-width:50%}.col-tablet-7{flex:0 0 58.3333333333%;max-width:58.3333333333%}.col-tablet-8{flex:0 0 66.6666666667%;max-width:66.6666666667%}.col-tablet-9{flex:0 0 75%;max-width:75%}.col-tablet-10{flex:0 0 83.3333333333%;max-width:83.3333333333%}.col-tablet-11{flex:0 0 91.6666666667%;max-width:91.6666666667%}.col-tablet-12{flex:0 0 100%;max-width:100%}}@media (min-width:64em){.col-desksm{flex-basis:0%;flex-grow:1;max-width:100%}.col-desksm-1{flex:0 0 8.3333333333%;max-width:8.3333333333%}.col-desksm-2{flex:0 0 16.6666666667%;max-width:16.6666666667%}.col-desksm-3{flex:0 0 25%;max-width:25%}.col-desksm-4{flex:0 0 33.3333333333%;max-width:33.3333333333%}.col-desksm-5{flex:0 0 41.6666666667%;max-width:41.6666666667%}.col-desksm-6{flex:0 0 50%;max-width:50%}.col-desksm-7{flex:0 0 58.3333333333%;max-width:58.3333333333%}.col-desksm-8{flex:0 0 66.6666666667%;max-width:66.6666666667%}.col-desksm-9{flex:0 0 75%;max-width:75%}.col-desksm-10{flex:0 0 83.3333333333%;max-width:83.3333333333%}.col-desksm-11{flex:0 0 91.6666666667%;max-width:91.6666666667%}.col-desksm-12{flex:0 0 100%;max-width:100%}}@media (min-width:80em){.col-deskxl{flex-basis:0%;flex-grow:1;max-width:100%}.col-deskxl-1{flex:0 0 8.3333333333%;max-width:8.3333333333%}.col-deskxl-2{flex:0 0 16.6666666667%;max-width:16.6666666667%}.col-deskxl-3{flex:0 0 25%;max-width:25%}.col-deskxl-4{flex:0 0 33.3333333333%;max-width:33.3333333333%}.col-deskxl-5{flex:0 0 41.6666666667%;max-width:41.6666666667%}.col-deskxl-6{flex:0 0 50%;max-width:50%}.col-deskxl-7{flex:0 0 58.3333333333%;max-width:58.3333333333%}.col-deskxl-8{flex:0 0 66.6666666667%;max-width:66.6666666667%}.col-deskxl-9{flex:0 0 75%;max-width:75%}.col-deskxl-10{flex:0 0 83.3333333333%;max-width:83.3333333333%}.col-deskxl-11{flex:0 0 91.6666666667%;max-width:91.6666666667%}.col-deskxl-12{flex:0 0 100%;max-width:100%}.offset-deskxl-1{margin-left:8.3333333333%}}[class*=row-gap]{display:grid;grid-column-gap:1rem;grid-row-gap:2rem}@media (min-width:83.75em){[class*=row-gap]{grid-column-gap:2.5rem}}.row-gap-4{grid-template-columns:1fr 1fr 1fr 1fr}.row-gap-3{grid-template-columns:1fr 1fr 1fr}.row-gap-2{grid-template-columns:1fr 1fr}@media (min-width:48em){.row-gap-tablet-4{grid-template-columns:1fr 1fr 1fr 1fr}.row-gap-tablet-3{grid-template-columns:1fr 1fr 1fr}.row-gap-tablet-2{grid-template-columns:1fr 1fr}}@media (min-width:64em){.row-gap-desksm-5{grid-template-columns:1fr 1fr 1fr 1fr 1fr}.row-gap-desksm-4{grid-template-columns:1fr 1fr 1fr 1fr}.row-gap-desksm-3{grid-template-columns:1fr 1fr 1fr}.row-gap-desksm-2{grid-template-columns:1fr 1fr}}@media (min-width:80em){.row-gap-deskxl-4{grid-template-columns:1fr 1fr 1fr 1fr}.row-gap-deskxl-3{grid-template-columns:1fr 1fr 1fr}.row-gap-deskxl-2{grid-template-columns:1fr 1fr}}.lay-sidebar{display:flex;fle ...
#     const getMyCookie = function getCookie(nameCookie) {
#     if (!nameCookie) return undefined;
#     var value = "; ".concat(typeof document !== 'undefined' ? document.cookie : '');
#     var parts = value.split("; ".concat(nameCookie, "="));
#     return parts.length === 2 ? parts.pop().split(';').shift() : undefined;
#   };
#
#     const gaIdCookie = getMyCookie('_ga');
#     const googleAnalyticsId =  gaIdCookie && gaIdCookie.split('.').splice(2,2).join('.');
#     const usuarioEmail = getMyCookie('usuarioemail');
#
#     (function (h, o, u, n, d) {
#         h = h[d] = h[d] || {
#           q: [],
#           onReady: function (c) {
#             h.q.push(c);
#           },
#         };
#         d = o.createElement(u);
#         d.async = 1;
#         d.src = n;
#         n = o.getElementsByTagName(u)[0];
#         n.parentNode.insertBefore(d, n);
#       })(
#         window,
#         document,
#         "script",
#         "https://www.datadoghq-browser-agent.com/datadog-logs-v5.js",
#         "DD_LOGS"
#       );
#       DD_LOGS.onReady(function () {
#         DD_LOGS.init({
#           clientToken: "pubaa01cb67f0a687a6eba4718413593f4f",
#           site: "datadoghq.com",
#           forwardErrorsToLogs: true,
#           sessionSampleRate: 1,
#           service: "lanacion-arc",
#           env: "prod",
#           version: "1493",
#           trackSessionAcrossSubdomains: false,
#         });
#
#         googleAnalyticsId && DD_LOGS.logger.setContextProperty('user.gaId', googleAnalyticsId);
#         usuarioEmail && DD_LOGS.logger.setContextProperty('user.email', usuarioEmail);
#
#         if ("prod" !== "prod")
#           console.log(
#             `Datadog initialized. Version: 1493, sampleRate: 1, env: prod`
#           );
#       });
#     </script><script async="" type="text/javascript">
#     (function (h, o, u, n, d) {
#         h = h[d] = h[d] || {
#           q: [],
#           onReady: function (c) {
#             h.q.push(c);
#           },
#         };
#         d = o.createElement(u);
#         d.async = 1;
#         d.src = n;
#         n = o.getElementsByTagName(u)[0];
#         n.parentNode.insertBefore(d, n);
#       })(
#         window,
#         document,
#         "script",
#         "https://www.datadoghq-browser-agent.com/datadog-rum-v5.js",
#         "DD_RUM"
#       );
#
#       DD_RUM.onReady(function () {
#         DD_RUM.init({
#           clientToken: "pubaa01cb67f0a687a6eba4718413593f4f",
#           applicationId: "bcea4545-f033-4b09-ab27-30995db5acb0",
#           site: "datadoghq.com",
#           service: "lanacion-arc",
#           env: "prod",
#           version: "1493",
#           sessionSampleRate: 0.15,
#           sessionReplaySampleRate: 30,
#           trackResources: true,
#           trackLongTasks: true,
#           trackUserInteractions: true,
#           trackSessionAcrossSubdomains: false,
#         });
#
#         DD_RUM.startSessionReplayRecording();
#
#         if (googleAnalyticsId || usuarioEmail) {
#           DD_RUM.setUser({
#             ...(googleAnalyticsId && { gaId: googleAnalyticsId }),
#             ...(usuarioEmail && { email: usuarioEmail })
#           });
#         }
#
#         if ("prod" !== "prod")
#             console.log(
#               `Datadog RUM initialized. Version: 1493, sampleRate: 0.15, env: prod`
#             );
#       });</script><script async="" data-article="{}" data-get-cookie="function getCookie(nameCookie) {
#     if (!nameCookie) return undefined;
#     var value = &quot;; &quot;.concat(typeof document !== 'undefined' ? document.cookie : '');
#     var parts = value.split(&quot;; &quot;.concat(nameCookie, &quot;=&quot;));
#     return parts.length === 2 ? parts.pop().split(';').shift() : undefined;
#   }" data-layout="LN10-Home_Main" id="script-permutive" src="/pf/resources/js/LN/Permutive.min.js?d=1493" type="text/javascript"></script><script async="" src="https://867f8423-d142-4fd1-ae8d-1a9bbbdf2358.edge.permutive.app/867f8423-d142-4fd1-ae8d-1a9bbbdf2358-web.js"></script><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-GHV6');</script><script defer="" id="comscore" type="text/javascript">var _comscore = _comscore || [];
#         _comscore.push({"c1":"2","c2":"6906398","options":{"enableFirstPartyCookie":true,"bypassUserConsentRequirementFor1PCookie":true}});(function() {
#             var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#             s.src = "https://sb.scorecardresearch.com/cs/6906398/beacon.js";
#             el.parentNode.insertBefore(s, el);
#             })();</script><noscript><img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=6906398&amp;cv=3.9.1&amp;cj=1"/></noscript><script async="" src=" https://securepubads.g.doubleclick.net/tag/js/gpt.js?network-code=133919216"></script><script async="" data-create-hash="function createHash(data) {
#   var encoder = new TextEncoder();
#   var dataBuffer = encoder.encode(data);
#   return crypto.subtle ? crypto.subtle.digest('SHA-256', dataBuffer).then(function (hashBuffer) {
#     if (hashBuffer) {
#       var hashArray = Array.from(new Uint8Array(hashBuffer));
#       return hashArray.map(function (_byte) {
#         return _byte.toString(16).padStart(2, '0');
#       }).join('');
#     }
#   }) : Promise.reject('crypto.subtle only works on HTTPS');
# }" data-get-cookie="function getCookie(nameCookie) {
#     if (!nameCookie) return undefined;
#     var value = &quot;; &quot;.concat(typeof document !== 'undefined' ? document.cookie : '');
#     var parts = value.split(&quot;; &quot;.concat(nameCookie, &quot;=&quot;));
#     return parts.length === 2 ? parts.pop().split(';').shift() : undefined;
#   }" data-new-tags="[]" id="googlePublisherTag-metadata" src="/pf/resources/js/LN/googlePublisherTagAcumulado.min.js?d=1493" type="text/javascript"></script><script async="" id="scriptAmazonPublisherServices" src="/pf/resources/js/LN/scriptAmazonPublisherServices.min.js?d=1493" type="text/javascript"></script><script type="text/javascript">!function(){"use strict";function e(e){var t=!(arguments.length>1&&void 0!==arguments[1])||arguments[1],c=document.createElement("script");c.src=e,t?c.type="module":(c.async=!0,c.type="text/javascript",c.setAttribute("nomodule",""));var n=document.getElementsByTagName("script")[0];n.parentNode.insertBefore(c,n)}!function(t,c){!function(t,c,n){var a,o,r;n.accountId=c,null!==(a=t.marfeel)&&void 0!==a||(t.marfeel={}),null!==(o=(r=t.marfeel).cmd)&&void 0!==o||(r.cmd=[]),t.marfeel.config=n;var i="https://sdk.mrf.io/statics";e("".concat(i,"/marfeel-sdk.js?id=").concat(c),!0),e("".concat(i,"/marfeel-sdk.es5.js?id=").concat(c),!1)}(t,c,arguments.length>2&&void 0!==arguments[2]?arguments[2]:{})}(window,3353 /* AccountId */,{} /* Config */)}();</script><script defer="" src="/pf/resources/js/common/eventsHelper.min.js?d=1493" type="application/javascript"></script><meta content="154042854349421" property="fb_app_id"/><meta content="website" property="og:type"/><meta content="Últimas noticias de Argentina y el mundo" property="og:title"/><meta content="LA NACION ofrece las últimas noticias, fotos y videos de la Argentina y el mundo. Política, economía, deportes y toda la información en tiempo real." property="og:description"/><meta content="https://arc-static.glanacion.com/pf/resources/images/placeholderLN.jpg?d=1493" property="og:image"/><meta content="512" property="og:image:width"/><meta content="768" property="og:image:height"/><meta content="https://www.lanacion.com.ar/" property="og:url"/><meta content="LA NACION" property="og:site_name"/><link href="https://www.lanacion.com.ar/" rel="canonical"/><meta content="Últimas noticias de Argentina y el mundo - LA NACION" name="title"/><meta content="LA NACION ofrece las últimas noticias, fotos y videos de la Argentina y el mundo. Política, economía, deportes y toda la información en tiempo real." name="description"/><script type="application/ld+json">{
#         "@context": "http://schema.org",
#         "@type": "NewsMediaOrganization",
#         "name": "LA NACION",
#         "url": "https://www.lanacion.com.ar/",
#         "description": "Últimas noticias de Argentina y el mundo – LA NACION",
#         "alternateName": "LN",
#         "diversityPolicy": "https://www.lanacion.com.ar/sociedad/diversidad-redaccion-nid2413327/",
#         "ethicsPolicy": "https://www.lanacion.com.ar/sociedad/la-nacion-mision-estructura-empresarial-principios-eticos-nid2393569/",
#         "masthead": "https://www.lanacion.com.ar/sociedad/equipo-editorial-la-nacion-nid2390490/",
#         "publishingPrinciples": "https://www.lanacion.com.ar/sociedad/los-veinte-20-principios-del-periodismo-la-nid2390521/",
#         "verificationFactCheckingPolicy": "https://www.lanacion.com.ar/sociedad/verificacion-chequeo-datos-nid2406825/",
#         "foundingDate": "1870-01-04",
#         "logo": {
#             "@context": "https://schema.org",
#             "@type": "ImageObject",
#             "url": "https://arc-static.glanacion.com/pf/resources/images/placeholderLN-112_amp.jpg?d=1493",
#             "height": 112,
#             "width": 112
#           },
#         "sameAs": [
#           "https://www.facebook.com/lanacion/",
#           "https://www.instagram.com/lanacioncom/",
#           "https://twitter.com/LANACION"
#         ]
#       }</script><script type="application/ld+json">{
#         "@context":"http://schema.org",
#         "@type":"WebSite",
#         "url":"https://www.lanacion.com.ar/"
#     }</script><link href="/pf/resources/images/favicon.ico?d=1493" rel="shortcut icon" type="image/x-icon"/><link href="/pf/resources/images/favicon-16.png?d=1493" rel="icon" sizes="16x16" type="image/png"/><link href="/pf/resources/images/favicon-32.png?d=1493" rel="icon" sizes="32x32" type="image/png"/><link href="/pf/resources/images/favicon-192.png?d=1493" rel="shortcut icon" sizes="192x192" type="image/png"/><link href="/pf/resources/images/favicon-512.png?d=1493" rel="shortcut icon" sizes="512x512" type="image/png"/><link href="/pf/resources/images/favicon-192.png?d=1493" rel="apple-touch-icon"/><link href="/pf/resources/images/favicon-512.png?d=1493" rel="apple-touch-icon" sizes="512x512"/><link href="/manifest.json" rel="manifest"/>
# <script>(window.BOOMR_mq=window.BOOMR_mq||[]).push(["addVar",{"rua.upush":"false","rua.cpush":"false","rua.upre":"false","rua.cpre":"false","rua.uprl":"false","rua.cprl":"false","rua.cprf":"false","rua.trans":"","rua.cook":"false","rua.ims":"false","rua.ufprl":"false","rua.cfprl":"false","rua.isuxp":"false","rua.texp":"norulematch"}]);</script>
# <script>!function(e){var n="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,n="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="FPXUV-CWEKR-ELG8D-URM4T-QZGQK",function(){function e(){if(!o){var e=document.createElement("script");e.id="boomr-scr-as",e.src=window.BOOMR.url,e.async=!0,i.parentNode.appendChild(e),o=!0}}function t(e){o=!0;var n,t,a,r,d=document,O=window;if(window.BOOMR.snippetMethod=e?"if":"i",t=function(e,n){var t=d.createElement("script");t.id=n||"boomr-if-as",t.src=window.BOOMR.url,BOOMR_lstart=(new Date).getTime(),e=e||d.body,e.appendChild(t)},!window.addEventListener&&window.attachEvent&&navigator.userAgent.match(/MSIE [67]\./))return window.BOOMR.snippetMethod="s",void t(i.parentNode,"boomr-async");a=document.createElement("IFRAME"),a.src="about:blank",a.title="",a.role="presentation",a.loading="eager",r=(a.frameElement||a).style,r.width=0,r.height=0,r.border=0,r.display="none",i.parentNode.appendChild(a);try{O=a.contentWindow,d=O.document.open()}catch(_){n=document.domain,a.src="javascript:var d=document.open();d.domain='"+n+"';void(0);",O=a.contentWindow,d=O.document.open()}if(n)d._boomrl=function(){this.domain=n,t()},d.write("<bo"+"dy onload='document._boomrl();'>");else if(O._boomrl=function(){t()},O.addEventListener)O.addEventListener("load",O._boomrl,!1);else if(O.attachEvent)O.attachEvent("onload",O._boomrl);d.close()}function a(e){window.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!window.BOOMR||!window.BOOMR.version&&!window.BOOMR.snippetExecuted){window.BOOMR=window.BOOMR||{},window.BOOMR.snippetStart=(new Date).getTime(),window.BOOMR.snippetExecuted=!0,window.BOOMR.snippetVersion=12,window.BOOMR.url=n+"FPXUV-CWEKR-ELG8D-URM4T-QZGQK";var i=document.currentScript||document.getElementsByTagName("script")[0],o=!1,r=document.createElement("link");if(r.relList&&"function"==typeof r.relList.supports&&r.relList.supports("preload")&&"as"in r)window.BOOMR.snippetMethod="p",r.href=window.BOOMR.url,r.rel="preload",r.as="script",r.addEventListener("load",e),r.addEventListener("error",function(){t(!0)}),setTimeout(function(){if(!o)t(!0)},3e3),BOOMR_lstart=(new Date).getTime(),i.parentNode.appendChild(r);else t(!1);if(window.addEventListener)window.addEventListener("load",a,!1);else if(window.attachEvent)window.attachEvent("onload",a)}}(),"".length>0)if(e&&"performance"in e&&e.performance&&"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var n=""=="true"?1:0,t="",a="wuodplvvd3ynszqawrja-f-3f54a9453-clientnsv4-s.akamaihd.net",i="false"=="true"?2:1,o={"ak.v":"37","ak.cp":"847416","ak.ai":parseInt("541075",10),"ak.ol":"0","ak.cr":24,"ak.ipv":4,"ak.proto":"http/1.1","ak.rid":"42464640","ak.r":38116,"ak.a2":n,"ak.m":"dscr","ak.n":"ff","ak.bpcip":"181.28.55.0","ak.cport":61533,"ak.gh":"181.30.240.213","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1711322194","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"172","ak.dpoabenc":"","ak.tf":i};if(""!==t)o["ak.ruds"]=t;var r={i:!1,av:function(n){var t="http.initiator";if(n&&(!n[t]||"spa_hard"===n[t]))o["ak.feo"]=void 0!==e.aFeoApplied?1:0,BOOMR.addVar(o)},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t","ak.tf"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={akVars:o,akDNSPreFetchDomain:a,init:function(){if(!r.i){var e=BOOMR.subscribe;e("before_beacon",r.av,null,null),e("onbeacon",r.rv,null,null),r.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script></head><body class="ln"><noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-GHV6" style="display:none;visibility:hidden" width="0"></iframe></noscrip ...

# %%
#comenzamos utilizando beautiful soup para encontrar el elemento'<main>', que tiene la clase 'main-container' en la variable soup.
portada= soup.find('main', class_='main-container')
#luego lo que realizamos, es que buscamos todos los elemntos '<a>', dentro del  elemento'<main>' y los almacenamos en esta variable.
a_href_values = portada.find_all('a')
#imprimimos las listas
print('\n', a_href_values)
print(type(a_href_values))
#iniciamos una lista vacia
f_values=[]
#iniciamos a recorer la lista que recorre todos los elementos '<a>' y obtiene el valor 'href' de cada uno almacenandolos en la lista 'links'
#iniciamos un loop que itera sobre cada elemento de 'a_href_values'
links = [link.get('href')]
for link in a_href_values:
#verificamos si el guión está presente en el valor actual del elemento '<a>', filtrando los enlaces que contienen un guión. Si el guión está presente, se agrega a la lista 'f_values'
    if "-" in value:
         f_values.append(f"https://www.lanacion.com.ar/{value}")
# Out:
#  [<a class="link ln-link flex flex-column --unstyled" href="/politica/24-de-marzo-que-dijo-estela-de-carlotto-sobre-el-golpe-y-la-vision-de-milei-y-villarruel-nid24032024/" target="_self" title="Día de la Memoria y reacción oficial. Estela Carlotto habló ante una Plaza de Mayo llena y criticó a Javier Milei"><section class="media-container" href="/politica/24-de-marzo-que-dijo-estela-de-carlotto-sobre-el-golpe-y-la-vision-de-milei-y-villarruel-nid24032024/" title="Estela Carlotto habló ante una Plaza de Mayo llena y criticó a Javier Milei"><picture class="ln-placeholder flex jc-center ai-center relative ratio-3-2"><source media="(min-width: 768px)" srcset="https://www.lanacion.com.ar/resizer/v2/estela-de-carlotto-critico-a-javier-milei-y-pidio-NWCVBDRVSRFRBNQJVSMCVDIFSM.JPG?auth=509cb169ee007d6b0deee39db9ce9fddea2d0b45dd844db1093792ea088ade5b&amp;width=488&amp;height=325&amp;quality=70&amp;smart=true"/><img alt="Estela Carlotto habló ante una Plaza de Mayo llena y criticó a Javier Milei" class="image flex w-100 h-100 --cover" decoding="async" fetchpriority="low" loading="lazy" src="https://www.lanacion.com.ar/resizer/v2/estela-de-carlotto-critico-a-javier-milei-y-pidio-NWCVBDRVSRFRBNQJVSMCVDIFSM.JPG?auth=509cb169ee007d6b0deee39db9ce9fddea2d0b45dd844db1093792ea088ade5b&amp;width=420&amp;height=280&amp;quality=70&amp;smart=true"/></picture></section><section class="description-container relative flex flex-column" href="/politica/24-de-marzo-que-dijo-estela-de-carlotto-sobre-el-golpe-y-la-vision-de-milei-y-villarruel-nid24032024/"><h1 class="text ln-text title --prumo --font-medium --font-4xl"><span class="text ln-text lead --prumo --font-extra">Día de la Memoria y reacción oficial.<!-- --> </span>Estela Carlotto habló ante una Plaza de Mayo llena y criticó a Javier Milei</h1><h2 class="text ln-text subhead --font-s">La presidenta de Abuelas de Plaza de Mayo pidió leyes contra el negacionismo; consideró que el Gobierno reflota “la teoría de los dos demonios”; “Que cambie o se vaya rápido”, sostuvo; Milei y Villarruel le respondieron</h2></section></a>, <a class="link ln-link flex flex-column --unstyled" href="/politica/el-gobierno-publico-un-spot-con-su-vision-sobre-el-24-de-marzo-nid24032024/" target="_self" title='"Memoria completa". El Gobierno publicó un spot con su versión sobre el 24 de marzo'><section class="media-container" href="/politica/el-gobierno-publico-un-spot-con-su-vision-sobre-el-24-de-marzo-nid24032024/" title="El Gobierno publicó un spot con su versión sobre el 24 de marzo"><div class="ln-placeholder flex jc-center ai-center relative ratio-3-2"><video autoplay="" class="ln-video" data-src="https://cdn.jwplayer.com/videos/db0Sz7Bq-kTExGaWf.mp4" disableremoteplayback="" loop="" muted="" playsinline="" poster="https://cdn.jwplayer.com/v2/media/db0Sz7Bq/poster.jpg?width=320"><source type="video/mp4"/></video></div></section><section class="description-container relative flex flex-column" href="/politica/el-gobierno-publico-un-spot-con-su-vision-sobre-el-24-de-marzo-nid24032024/"><span class="ln-badge inline-flex w-fit ai-center rounded-16 text-12 z-1 flex-nowrap overflow-hidden bg-black text-light-0 uppercase py-6 px-8 --negative">VIDEO</span><h2 class="text ln-text title --prumo --font-medium --font-m-l"><span class="text ln-text lead --prumo --font-extra">"Memoria completa".<!-- --> </span>El Gobierno publicó un spot con su versión sobre el 24 de marzo</h2></section></a>, <a class="link ln-link flex flex-column --unstyled" href="/politica/javier-milei-en-vivo-las-ultimas-medidas-del-gobierno-nid24032024/" target="_self" title='"Solo cuando gobiernan ellos". Martín Menem atacó al kirchnerismo y los organismos de DD.HH.'><section class="media-container" href="/politica/javier-milei-en-vivo-las-ultimas-medidas-del-gobierno-nid24032024/" title="Martín Menem atacó al kirchnerismo y los organismos de DD.HH."><picture class="ln-placeholder flex jc-center ai-center relative ratio-3-2"><source media="(max-width: 767px)"  ...
# <class 'bs4.element.ResultSet'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[101], line 12
#       9 f_values=[]
#      10 #iniciamos a recorer la lista que recorre todos los elementos '<a>' y obtiene el valor 'href' de cada uno almacenandolos en la lista 'links'
#      11 #iniciamos un loop que itera sobre cada elemento de 'a_href_values'
# ---> 12 links = [link.get('href')]
#      13 for link in a_href_values:
#      14 #verificamos si el guión está presente en el valor actual del elemento '<a>', filtrando los enlaces que contienen un guión. Si el guión está presente, se agrega a la lista 'f_values'
#      15     if "-" in value:
#
# NameError: name 'link' is not defined

# %%
#guardamos en un dataframe
link_df = pd.DataFrame(f_values)

# %%
#exportamos a un excel
link_df.to_excel('links.xlsx',index=False)
